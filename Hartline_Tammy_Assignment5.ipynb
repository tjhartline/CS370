# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

# No changes made - original version
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  


EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995 

class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  

# Changed Exploration max to 0.8
EXPLORATION_MAX = 0.8
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995 

class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  

# Changed Exploration min to 0.013
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.013  
EXPLORATION_DECAY = 0.995 

class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  

# Changed Exploration decay 0.905
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01 
EXPLORATION_DECAY = 0.905

class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

GAMMA = 0.95  
# Changed learning rate to 0.004
LEARNING_RATE = 0.004  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  

# Changed Exploration decay to 0.905
EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01 
EXPLORATION_DECAY = 0.905

class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  

# Changed gamma to 0.90
GAMMA = 0.90  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  

EXPLORATION_MAX = 1.0
EXPLORATION_MIN = 0.01 
EXPLORATION_DECAY = 0.995

class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole() # Changed gamma to 0.9
           # Solved in 76 runs, 176 runs total.
# Out:
# Run: 1, exploration: 1.0, score: 11
# Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.8603841919146962, score: 39
# Scores: (min: 11, avg: 25, max: 39)
#
# Run: 3, exploration: 0.8020760579717637, score: 15
# Scores: (min: 11, avg: 21.666666666666668, max: 39)
#
# Run: 4, exploration: 0.7147372386831305, score: 24
# Scores: (min: 11, avg: 22.25, max: 39)
#
# Run: 5, exploration: 0.6242658676435396, score: 28
# Scores: (min: 11, avg: 23.4, max: 39)
#
# Run: 6, exploration: 0.5848838636585911, score: 14
# Scores: (min: 11, avg: 21.833333333333332, max: 39)
#
# Run: 7, exploration: 0.5371084840724134, score: 18
# Scores: (min: 11, avg: 21.285714285714285, max: 39)
#
# Run: 8, exploration: 0.500708706245853, score: 15
# Scores: (min: 11, avg: 20.5, max: 39)
#
# Run: 9, exploration: 0.47862223409330756, score: 10
# Scores: (min: 10, avg: 19.333333333333332, max: 39)
#
# Run: 10, exploration: 0.40565285250151817, score: 34
# Scores: (min: 10, avg: 20.8, max: 39)
#
# Run: 11, exploration: 0.322118930542046, score: 47
# Scores: (min: 10, avg: 23.181818181818183, max: 47)
#
# Run: 12, exploration: 0.23371867538818816, score: 65
# Scores: (min: 10, avg: 26.666666666666668, max: 65)
#
# Run: 13, exploration: 0.22453190559909803, score: 9
# Scores: (min: 9, avg: 25.307692307692307, max: 65)
#
# Run: 14, exploration: 0.20722748400265262, score: 17
# Scores: (min: 9, avg: 24.714285714285715, max: 65)
#
# Run: 15, exploration: 0.1865228530605915, score: 22
# Scores: (min: 9, avg: 24.533333333333335, max: 65)
#
# Run: 16, exploration: 0.1549480222912372, score: 38
# Scores: (min: 9, avg: 25.375, max: 65)
#
# Run: 17, exploration: 0.14016760486247823, score: 21
# Scores: (min: 9, avg: 25.11764705882353, max: 65)
#
# Run: 18, exploration: 0.12059799144222175, score: 31
# Scores: (min: 9, avg: 25.444444444444443, max: 65)
#
# Run: 19, exploration: 0.1135578192100607, score: 13
# Scores: (min: 9, avg: 24.789473684210527, max: 65)
#
# Run: 20, exploration: 0.0996820918179746, score: 27
# Scores: (min: 9, avg: 24.9, max: 65)
#
# Run: 21, exploration: 0.08706434220766679, score: 28
# Scores: (min: 9, avg: 25.047619047619047, max: 65)
#
# Run: 22, exploration: 0.06878996970981359, score: 48
# Scores: (min: 9, avg: 26.09090909090909, max: 65)
#
# Run: 23, exploration: 0.05743227569078546, score: 37
# Scores: (min: 9, avg: 26.565217391304348, max: 65)
#
# Run: 24, exploration: 0.0451506389749415, score: 49
# Scores: (min: 9, avg: 27.5, max: 65)
#
# Run: 25, exploration: 0.032433008066058915, score: 67
# Scores: (min: 9, avg: 29.08, max: 67)
#
# Run: 26, exploration: 0.021181128426399323, score: 86
# Scores: (min: 9, avg: 31.26923076923077, max: 86)
#
# Run: 27, exploration: 0.014471156162198668, score: 77
# Scores: (min: 9, avg: 32.96296296296296, max: 86)
#
# Run: 28, exploration: 0.010036634861955105, score: 74
# Scores: (min: 9, avg: 34.42857142857143, max: 86)
#
# Run: 29, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 36.62068965517241, max: 98)
#
# Run: 30, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 41.4, max: 180)
#
# Run: 31, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 44.29032258064516, max: 180)
#
# Run: 32, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 48, max: 180)
#
# Run: 33, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 52.81818181818182, max: 207)
#
# Run: 34, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 56.705882352941174, max: 207)
#
# Run: 35, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 60.285714285714285, max: 207)
#
# Run: 36, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 63.416666666666664, max: 207)
#
# Run: 37, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 65.5945945945946, max: 207)
#
# Run: 38, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 67.52631578947368, max: 207)
#
# Run: 39, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 69.33333333333333, max: 207)
#
# Run: 40, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 71.275, max: 207)
#
# Run: 41, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 73.1219512195122, max: 207)
#
# Run: 42, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 74.76190476190476, max: 207)
#
# Run: 43, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 76.83720930232558, max: 207)
#
# Run: 44, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 78.0909090909091, max: 207)
#
# Run: 45, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 79.75555555555556, max: 207)
#
# Run: 46, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 81.45652173913044, max: 207)
#
# Run: 47, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 82.63829787234043, max: 207)
#
# Run: 48, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 83.8125, max: 207)
#
# Run: 49, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 84.95918367346938, max: 207)
#
# Run: 50, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 86.32, max: 207)
#
# Run: 51, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 87.52941176470588, max: 207)
#
# Run: 52, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 88.8076923076923, max: 207)
#
# Run: 53, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 90.9245283018868, max: 207)
#
# Run: 54, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 92, max: 207)
#
# Run: 55, exploration: 0.01, score: 281
# Scores: (min: 9, avg: 95.43636363636364, max: 281)
#
# Run: 56, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 95.98214285714286, max: 281)
#
# Run: 57, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 97.52631578947368, max: 281)
#
# Run: 58, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 98.5, max: 281)
#
# Run: 59, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 99.38983050847457, max: 281)
#
# Run: 60, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 99.98333333333333, max: 281)
#
# Run: 61, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 100.62295081967213, max: 281)
#
# Run: 62, exploration: 0.01, score: 211
# Scores: (min: 9, avg: 102.40322580645162, max: 281)
#
# Run: 63, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 102.85714285714286, max: 281)
#
# Run: 64, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 102.890625, max: 281)
#
# Run: 65, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 103.36923076923077, max: 281)
#
# Run: 66, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 103.86363636363636, max: 281)
#
# Run: 67, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 104.59701492537313, max: 281)
#
# Run: 68, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 104.91176470588235, max: 281)
#
# Run: 69, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 105.08695652173913, max: 281)
#
# Run: 70, exploration: 0.01, score: 187
# Scores: (min: 9, avg: 106.25714285714285, max: 281)
#
# Run: 71, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 108.08450704225352, max: 281)
#
# Run: 72, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 108.76388888888889, max: 281)
#
# Run: 73, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 109.5068493150685, max: 281)
#
# Run: 74, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 109.75675675675676, max: 281)
#
# Run: 75, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 110.48, max: 281)
#
# Run: 76, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 110.6842105263158, max: 281)
#
# Run: 77, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 111.1038961038961, max: 281)
#
# Run: 78, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 111.94871794871794, max: 281)
#
# Run: 79, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 112.60759493670886, max: 281)
#
# Run: 80, exploration: 0.01, score: 418
# Scores: (min: 9, avg: 116.425, max: 418)
#
# Run: 81, exploration: 0.01, score: 159
# Scores: (min: 9, avg: 116.95061728395062, max: 418)
#
# Run: 82, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 117.40243902439025, max: 418)
#
# Run: 83, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 117.7710843373494, max: 418)
#
# Run: 84, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 118.23809523809524, max: 418)
#
# Run: 85, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 119.4, max: 418)
#
# Run: 86, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 119.84883720930233, max: 418)
#
# Run: 87, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 119.71264367816092, max: 418)
#
# Run: 88, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 119.80681818181819, max: 418)
#
# Run: 89, exploration: 0.01, score: 144
# Scores: (min: 9, avg: 120.07865168539325, max: 418)
# Run: 90, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 120.04444444444445, max: 418)
#
# Run: 91, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 120.25274725274726, max: 418)
#
# Run: 92, exploration: 0.01, score: 291
# Scores: (min: 9, avg: 122.1086956521739, max: 418)
#
# Run: 93, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 122.56989247311827, max: 418)
#
# Run: 94, exploration: 0.01, score: 148
# Scores: (min: 9, avg: 122.84042553191489, max: 418)
#
# Run: 95, exploration: 0.01, score: 155
# Scores: (min: 9, avg: 123.17894736842105, max: 418)
#
# Run: 96, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 123.67708333333333, max: 418)
#
# Run: 97, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 124.36082474226804, max: 418)
#
# Run: 98, exploration: 0.01, score: 207
# Scores: (min: 9, avg: 125.20408163265306, max: 418)
#
# Run: 99, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 125.34343434343434, max: 418)
#
# Run: 100, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 125.58, max: 418)
#
# Run: 101, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 127.23, max: 418)
#
# Run: 102, exploration: 0.01, score: 182
# Scores: (min: 9, avg: 128.66, max: 418)
#
# Run: 103, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 130.14, max: 418)
#
# Run: 104, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 131.74, max: 418)
#
# Run: 105, exploration: 0.01, score: 132
# Scores: (min: 9, avg: 132.78, max: 418)
#
# Run: 106, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 134.18, max: 418)
#
# Run: 107, exploration: 0.01, score: 286
# Scores: (min: 9, avg: 136.86, max: 418)
#
# Run: 108, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 138.43, max: 418)
#
# Run: 109, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 139.44, max: 418)
#
# Run: 110, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 140.75, max: 418)
#
# Run: 111, exploration: 0.01, score: 303
# Scores: (min: 9, avg: 143.31, max: 418)
#
# Run: 112, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 144.17, max: 418)
#
# Run: 113, exploration: 0.01, score: 166
# Scores: (min: 13, avg: 145.74, max: 418)
#
# Run: 114, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 150.57, max: 500)
#
# Run: 115, exploration: 0.01, score: 235
# Scores: (min: 13, avg: 152.7, max: 500)
#
# Run: 116, exploration: 0.01, score: 158
# Scores: (min: 13, avg: 153.9, max: 500)
#
# Run: 117, exploration: 0.01, score: 262
# Scores: (min: 13, avg: 156.31, max: 500)
#
# Run: 118, exploration: 0.01, score: 91
# Scores: (min: 13, avg: 156.91, max: 500)
#
# Run: 119, exploration: 0.01, score: 179
# Scores: (min: 27, avg: 158.57, max: 500)
#
# Run: 120, exploration: 0.01, score: 328
# Scores: (min: 28, avg: 161.58, max: 500)
#
# Run: 121, exploration: 0.01, score: 177
# Scores: (min: 37, avg: 163.07, max: 500)
#
# Run: 122, exploration: 0.01, score: 159
# Scores: (min: 37, avg: 164.18, max: 500)
#
# Run: 123, exploration: 0.01, score: 16
# Scores: (min: 16, avg: 163.97, max: 500)
#
# Run: 124, exploration: 0.01, score: 63
# Scores: (min: 16, avg: 164.11, max: 500)
#
# Run: 125, exploration: 0.01, score: 335
# Scores: (min: 16, avg: 166.79, max: 500)
#
# Run: 126, exploration: 0.01, score: 136
# Scores: (min: 16, avg: 167.29, max: 500)
#
# Run: 127, exploration: 0.01, score: 65
# Scores: (min: 16, avg: 167.17, max: 500)
#
# Run: 128, exploration: 0.01, score: 120
# Scores: (min: 16, avg: 167.63, max: 500)
#
# Run: 129, exploration: 0.01, score: 267
# Scores: (min: 16, avg: 169.32, max: 500)
#
# Run: 130, exploration: 0.01, score: 276
# Scores: (min: 16, avg: 170.28, max: 500)
#
# Run: 131, exploration: 0.01, score: 189
# Scores: (min: 16, avg: 170.86, max: 500)
#
# Run: 132, exploration: 0.01, score: 265
# Scores: (min: 16, avg: 171.88, max: 500)
#
# Run: 133, exploration: 0.01, score: 241
# Scores: (min: 16, avg: 172.22, max: 500)
#
# Run: 134, exploration: 0.01, score: 153
# Scores: (min: 16, avg: 171.9, max: 500)
#
# Run: 135, exploration: 0.01, score: 234
# Scores: (min: 16, avg: 172.42, max: 500)
#
# Run: 136, exploration: 0.01, score: 217
# Scores: (min: 16, avg: 172.86, max: 500)
#
# Run: 137, exploration: 0.01, score: 180
# Scores: (min: 16, avg: 173.22, max: 500)
#
# Run: 138, exploration: 0.01, score: 185
# Scores: (min: 16, avg: 173.68, max: 500)
#
# Run: 139, exploration: 0.01, score: 165
# Scores: (min: 16, avg: 173.95, max: 500)
#
# Run: 140, exploration: 0.01, score: 198
# Scores: (min: 16, avg: 174.46, max: 500)
#
# Run: 141, exploration: 0.01, score: 57
# Scores: (min: 16, avg: 173.56, max: 500)
#
# Run: 142, exploration: 0.01, score: 67
# Scores: (min: 16, avg: 172.81, max: 500)
#
# Run: 143, exploration: 0.01, score: 156
# Scores: (min: 16, avg: 172.73, max: 500)
#
# Run: 144, exploration: 0.01, score: 270
# Scores: (min: 16, avg: 174.11, max: 500)
#
# Run: 145, exploration: 0.01, score: 206
# Scores: (min: 16, avg: 174.64, max: 500)
#
# Run: 146, exploration: 0.01, score: 175
# Scores: (min: 16, avg: 174.81, max: 500)
#
# Run: 147, exploration: 0.01, score: 270
# Scores: (min: 16, avg: 176.14, max: 500)
#
# Run: 148, exploration: 0.01, score: 101
# Scores: (min: 16, avg: 175.76, max: 500)
#
# Run: 149, exploration: 0.01, score: 167
# Scores: (min: 16, avg: 176.03, max: 500)
#
# Run: 150, exploration: 0.01, score: 225
# Scores: (min: 16, avg: 176.75, max: 500)
#
# Run: 151, exploration: 0.01, score: 214
# Scores: (min: 16, avg: 177.41, max: 500)
#
# Run: 152, exploration: 0.01, score: 57
# Scores: (min: 16, avg: 176.44, max: 500)
#
# Run: 153, exploration: 0.01, score: 39
# Scores: (min: 16, avg: 174.82, max: 500)
#
# Run: 154, exploration: 0.01, score: 251
# Scores: (min: 16, avg: 175.84, max: 500)
#
# Run: 155, exploration: 0.01, score: 155
# Scores: (min: 16, avg: 174.58, max: 500)
#
# Run: 156, exploration: 0.01, score: 141
# Scores: (min: 16, avg: 174.73, max: 500)
#
# Run: 157, exploration: 0.01, score: 254
# Scores: (min: 16, avg: 175.43, max: 500)
#
# Run: 158, exploration: 0.01, score: 272
# Scores: (min: 16, avg: 176.61, max: 500)
#
# Run: 159, exploration: 0.01, score: 124
# Scores: (min: 16, avg: 176.34, max: 500)
#
# Run: 160, exploration: 0.01, score: 196
# Scores: (min: 16, avg: 176.95, max: 500)
#
# Run: 161, exploration: 0.01, score: 278
# Scores: (min: 16, avg: 178.34, max: 500)
#
# Run: 162, exploration: 0.01, score: 119
# Scores: (min: 16, avg: 177.42, max: 500)
#
# Run: 163, exploration: 0.01, score: 138
# Scores: (min: 16, avg: 177.49, max: 500)
#
# Run: 164, exploration: 0.01, score: 162
# Scores: (min: 16, avg: 178.06, max: 500)
#
# Run: 165, exploration: 0.01, score: 93
# Scores: (min: 16, avg: 177.65, max: 500)
#
# Run: 166, exploration: 0.01, score: 182
# Scores: (min: 16, avg: 178.11, max: 500)
#
# Run: 167, exploration: 0.01, score: 133
# Scores: (min: 16, avg: 177.91, max: 500)
#
# Run: 168, exploration: 0.01, score: 500
# Scores: (min: 16, avg: 181.65, max: 500)
#
# Run: 169, exploration: 0.01, score: 368
# Scores: (min: 16, avg: 184.16, max: 500)
#
# Run: 170, exploration: 0.01, score: 445
# Scores: (min: 16, avg: 186.74, max: 500)
#
# Run: 171, exploration: 0.01, score: 373
# Scores: (min: 16, avg: 188.11, max: 500)
#
# Run: 172, exploration: 0.01, score: 82
# Scores: (min: 16, avg: 187.36, max: 500)
#
# Run: 173, exploration: 0.01, score: 361
# Scores: (min: 16, avg: 189.34, max: 500)
#
# Run: 174, exploration: 0.01, score: 500
# Scores: (min: 16, avg: 193.06, max: 500)
#
# Run: 175, exploration: 0.01, score: 195
# Scores: (min: 16, avg: 193.37, max: 500)
#
# Run: 176, exploration: 0.01, score: 314
# Scores: (min: 16, avg: 195.25, max: 500)
#
# Solved in 76 runs, 176 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-d5bad85edc31> in <module>
# ----> 1 cartpole() # Changed gamma to 0.9
#
# <ipython-input-16-de252ccf65c7> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
cartpole() # Changed learning rate to 0.004 and decay to 0.905
           # Force stopped running after 1195 runs over an hour period
# Out:
# Run: 1, exploration: 1.0, score: 10
# Scores: (min: 10, avg: 10, max: 10)
#
# Run: 2, exploration: 0.5494035676106407, score: 16
# Scores: (min: 10, avg: 13, max: 16)
#
# Run: 3, exploration: 0.15008006353821474, score: 14
# Scores: (min: 10, avg: 13.333333333333334, max: 16)
#
# Run: 4, exploration: 0.0553106544202557, score: 11
# Scores: (min: 10, avg: 12.75, max: 16)
#
# Run: 5, exploration: 0.02252402547163457, score: 10
# Scores: (min: 10, avg: 12.2, max: 16)
#
# Run: 6, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 12, max: 16)
#
# Run: 7, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 11.857142857142858, max: 16)
#
# Run: 8, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 11.625, max: 16)
#
# Run: 9, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 11.777777777777779, max: 16)
#
# Run: 10, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 12, max: 16)
#
# Run: 11, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 12, max: 16)
#
# Run: 12, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 12.666666666666666, max: 20)
#
# Run: 13, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 12.538461538461538, max: 20)
#
# Run: 14, exploration: 0.01, score: 30
# Scores: (min: 10, avg: 13.785714285714286, max: 30)
#
# Run: 15, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 13.466666666666667, max: 30)
#
# Run: 16, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 13.25, max: 30)
#
# Run: 17, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 13.117647058823529, max: 30)
#
# Run: 18, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.88888888888889, max: 30)
#
# Run: 19, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 15.473684210526315, max: 62)
#
# Run: 20, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 16.4, max: 62)
#
# Run: 21, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 17.714285714285715, max: 62)
#
# Run: 22, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 18.181818181818183, max: 62)
#
# Run: 23, exploration: 0.01, score: 41
# Scores: (min: 9, avg: 19.17391304347826, max: 62)
#
# Run: 24, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 22.083333333333332, max: 89)
#
# Run: 25, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 23.72, max: 89)
#
# Run: 26, exploration: 0.01, score: 127
# Scores: (min: 9, avg: 27.692307692307693, max: 127)
#
# Run: 27, exploration: 0.01, score: 86
# Scores: (min: 9, avg: 29.85185185185185, max: 127)
#
# Run: 28, exploration: 0.01, score: 85
# Scores: (min: 9, avg: 31.821428571428573, max: 127)
#
# Run: 29, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 34.06896551724138, max: 127)
#
# Run: 30, exploration: 0.01, score: 131
# Scores: (min: 9, avg: 37.3, max: 131)
#
# Run: 31, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 40.516129032258064, max: 137)
#
# Run: 32, exploration: 0.01, score: 373
# Scores: (min: 9, avg: 50.90625, max: 373)
#
# Run: 33, exploration: 0.01, score: 441
# Scores: (min: 9, avg: 62.72727272727273, max: 441)
#
# Run: 34, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 64.70588235294117, max: 441)
#
# Run: 35, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 66.25714285714285, max: 441)
#
# Run: 36, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 67.22222222222223, max: 441)
#
# Run: 37, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 67.08108108108108, max: 441)
#
# Run: 38, exploration: 0.01, score: 244
# Scores: (min: 9, avg: 71.73684210526316, max: 441)
#
# Run: 39, exploration: 0.01, score: 347
# Scores: (min: 9, avg: 78.7948717948718, max: 441)
#
# Run: 40, exploration: 0.01, score: 415
# Scores: (min: 9, avg: 87.2, max: 441)
#
# Run: 41, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 85.41463414634147, max: 441)
#
# Run: 42, exploration: 0.01, score: 319
# Scores: (min: 9, avg: 90.97619047619048, max: 441)
#
# Run: 43, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 89.55813953488372, max: 441)
#
# Run: 44, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 90.86363636363636, max: 441)
#
# Run: 45, exploration: 0.01, score: 219
# Scores: (min: 9, avg: 93.71111111111111, max: 441)
#
# Run: 46, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 95.67391304347827, max: 441)
#
# Run: 47, exploration: 0.01, score: 473
# Scores: (min: 9, avg: 103.70212765957447, max: 473)
#
# Run: 48, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 105.25, max: 473)
#
# Run: 49, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 104.77551020408163, max: 473)
#
# Run: 50, exploration: 0.01, score: 221
# Scores: (min: 9, avg: 107.1, max: 473)
#
# Run: 51, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 109.41176470588235, max: 473)
#
# Run: 52, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 111.26923076923077, max: 473)
#
# Run: 53, exploration: 0.01, score: 200
# Scores: (min: 9, avg: 112.94339622641509, max: 473)
#
# Run: 54, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 114.27777777777777, max: 473)
#
# Run: 55, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 121.2909090909091, max: 500)
#
# Run: 56, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 121.85714285714286, max: 500)
#
# Run: 57, exploration: 0.01, score: 250
# Scores: (min: 9, avg: 124.10526315789474, max: 500)
#
# Run: 58, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 124.56896551724138, max: 500)
#
# Run: 59, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 124.15254237288136, max: 500)
#
# Run: 60, exploration: 0.01, score: 361
# Scores: (min: 9, avg: 128.1, max: 500)
#
# Run: 61, exploration: 0.01, score: 65
# Scores: (min: 9, avg: 127.06557377049181, max: 500)
#
# Run: 62, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 126.7258064516129, max: 500)
#
# Run: 63, exploration: 0.01, score: 158
# Scores: (min: 9, avg: 127.22222222222223, max: 500)
#
# Run: 64, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 126.21875, max: 500)
#
# Run: 65, exploration: 0.01, score: 125
# Scores: (min: 9, avg: 126.2, max: 500)
#
# Run: 66, exploration: 0.01, score: 249
# Scores: (min: 9, avg: 128.06060606060606, max: 500)
#
# Run: 67, exploration: 0.01, score: 305
# Scores: (min: 9, avg: 130.70149253731344, max: 500)
#
# Run: 68, exploration: 0.01, score: 307
# Scores: (min: 9, avg: 133.2941176470588, max: 500)
#
# Run: 69, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 132.71014492753622, max: 500)
#
# Run: 70, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 131.0142857142857, max: 500)
#
# Run: 71, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 131.05633802816902, max: 500)
#
# Run: 72, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 130.91666666666666, max: 500)
#
# Run: 73, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 130.73972602739727, max: 500)
#
# Run: 74, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 130.98648648648648, max: 500)
#
# Run: 75, exploration: 0.01, score: 79
# Scores: (min: 9, avg: 130.29333333333332, max: 500)
#
# Run: 76, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 130.03947368421052, max: 500)
#
# Run: 77, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 130.32467532467533, max: 500)
#
# Run: 78, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 130.1153846153846, max: 500)
#
# Run: 79, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 130.37974683544303, max: 500)
#
# Run: 80, exploration: 0.01, score: 117
# Scores: (min: 9, avg: 130.2125, max: 500)
#
# Run: 81, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 130.1851851851852, max: 500)
#
# Run: 82, exploration: 0.01, score: 268
# Scores: (min: 9, avg: 131.8658536585366, max: 500)
#
# Run: 83, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 132.44578313253012, max: 500)
#
# Run: 84, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 132.17857142857142, max: 500)
#
# Run: 85, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 132.05882352941177, max: 500)
#
# Run: 86, exploration: 0.01, score: 143
# Scores: (min: 9, avg: 132.1860465116279, max: 500)
#
# Run: 87, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 131.93103448275863, max: 500)
#
# Run: 88, exploration: 0.01, score: 276
# Scores: (min: 9, avg: 133.5681818181818, max: 500)
#
# Run: 89, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 132.3370786516854, max: 500)
#
# Run: 90, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 130.96666666666667, max: 500)
#
# Run: 91, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 129.63736263736263, max: 500)
#
# Run: 92, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 128.33695652173913, max: 500)
#
# Run: 93, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 127.05376344086021, max: 500)
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 125.80851063829788, max: 500)
#
# Run: 95, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 124.57894736842105, max: 500)
#
# Run: 96, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 123.38541666666667, max: 500)
#
# Run: 97, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 122.20618556701031, max: 500)
#
# Run: 98, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 121.06122448979592, max: 500)
#
# Run: 99, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 119.92929292929293, max: 500)
#
# Run: 100, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 118.83, max: 500)
#
# Run: 101, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 118.83, max: 500)
#
# Run: 102, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 118.77, max: 500)
#
# Run: 103, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 118.71, max: 500)
#
# Run: 104, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 118.71, max: 500)
#
# Run: 105, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 118.71, max: 500)
#
# Run: 106, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 118.7, max: 500)
#
# Run: 107, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.68, max: 500)
#
# Run: 108, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.67, max: 500)
#
# Run: 109, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 118.65, max: 500)
#
# Run: 110, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 118.61, max: 500)
#
# Run: 111, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 118.59, max: 500)
#
# Run: 112, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 118.49, max: 500)
#
# Run: 113, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.47, max: 500)
#
# Run: 114, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.26, max: 500)
#
# Run: 115, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.26, max: 500)
#
# Run: 116, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.25, max: 500)
#
# Run: 117, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 118.23, max: 500)
#
# Run: 118, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 118.22, max: 500)
#
# Run: 119, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.7, max: 500)
#
# Run: 120, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.46, max: 500)
#
# Run: 121, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 117.12, max: 500)
#
# Run: 122, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 116.94, max: 500)
#
# Run: 123, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 116.62, max: 500)
#
# Run: 124, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 115.82, max: 500)
#
# Run: 125, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 115.29, max: 500)
#
# Run: 126, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 114.12, max: 500)
#
# Run: 127, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 113.36, max: 500)
#
# Run: 128, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 112.61, max: 500)
#
# Run: 129, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 111.74, max: 500)
#
# Run: 130, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 110.52, max: 500)
#
# Run: 131, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 109.23, max: 500)
#
# Run: 132, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 105.58, max: 500)
#
# Run: 133, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 101.27, max: 500)
#
# Run: 134, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 100.07, max: 500)
#
# Run: 135, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 98.97, max: 500)
#
# Run: 136, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 98.06, max: 500)
#
# Run: 137, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 97.54, max: 500)
#
# Run: 138, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 95.2, max: 500)
#
# Run: 139, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 91.82, max: 500)
#
# Run: 140, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 87.76, max: 500)
#
# Run: 141, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 87.71, max: 500)
#
# Run: 142, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 84.6, max: 500)
#
# Run: 143, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 84.4, max: 500)
#
# Run: 144, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 83.03, max: 500)
#
# Run: 145, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 80.95, max: 500)
#
# Run: 146, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 79.2, max: 500)
#
# Run: 147, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 74.56, max: 500)
#
# Run: 148, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 72.88, max: 500)
#
# Run: 149, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 72.15, max: 500)
#
# Run: 150, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 70.04, max: 500)
#
# Run: 151, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 67.88, max: 500)
#
# Run: 152, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 65.91, max: 500)
#
# Run: 153, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 64, max: 500)
#
# Run: 154, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 62.24, max: 500)
#
# Run: 155, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 57.34, max: 361)
#
# Run: 156, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 55.9, max: 361)
#
# Run: 157, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 53.49, max: 361)
#
# Run: 158, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 52.08, max: 361)
#
# Run: 159, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 51.17, max: 361)
#
# Run: 160, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 47.65, max: 307)
#
# Run: 161, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 47.09, max: 307)
#
# Run: 162, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 46.11, max: 307)
#
# Run: 163, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 44.61, max: 307)
#
# Run: 164, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 44.07, max: 307)
#
# Run: 165, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 42.92, max: 307)
#
# Run: 166, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.52, max: 307)
#
# Run: 167, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 37.56, max: 307)
#
# Run: 168, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 34.58, max: 276)
#
# Run: 169, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 33.73, max: 276)
#
# Run: 170, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 33.68, max: 276)
#
# Run: 171, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 32.43, max: 276)
#
# Run: 172, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.31, max: 276)
#
# Run: 173, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.22, max: 276)
#
# Run: 174, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 28.81, max: 276)
#
# Run: 175, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 28.12, max: 276)
#
# Run: 176, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 27.09, max: 276)
#
# Run: 177, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 25.66, max: 276)
#
# Run: 178, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 24.6, max: 276)
#
# Run: 179, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 23.19, max: 276)
#
# Run: 180, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 22.12, max: 276)
#
# Run: 181, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 20.93, max: 276)
#
# Run: 182, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 18.35, max: 276)
#
# Run: 183, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.68, max: 276)
#
# Run: 184, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 15.66, max: 276)
#
# Run: 185, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 14.52, max: 276)
#
# Run: 186, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.18, max: 276)
#
# Run: 187, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.19, max: 276)
#
# Run: 188, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.53, max: 24)
#
# Run: 189, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 13)
#
# Run: 190, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 13)
#
# Run: 191, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 13)
#
# Run: 192, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.38, max: 13)
#
# Run: 193, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 13)
#
# Run: 194, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.37, max: 13)
#
# Run: 195, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.36, max: 13)
#
# Run: 196, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 197, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.35, max: 13)
# Run: 198, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 199, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 200, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 201, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 202, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 203, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.36, max: 13)
#
# Run: 204, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.36, max: 13)
#
# Run: 205, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.36, max: 13)
#
# Run: 206, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 207, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.35, max: 13)
#
# Run: 208, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.36, max: 13)
#
# Run: 209, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.34, max: 13)
#
# Run: 210, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.32, max: 13)
#
# Run: 211, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.32, max: 13)
#
# Run: 212, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.3, max: 13)
#
# Run: 213, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.31, max: 13)
#
# Run: 214, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.31, max: 13)
#
# Run: 215, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.32, max: 13)
#
# Run: 216, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 217, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.38, max: 15)
#
# Run: 218, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 219, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 220, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 221, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 222, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.39, max: 15)
#
# Run: 223, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.41, max: 15)
#
# Run: 224, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 9.55, max: 23)
#
# Run: 225, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.55, max: 23)
#
# Run: 226, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.54, max: 23)
#
# Run: 227, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.54, max: 23)
#
# Run: 228, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.53, max: 23)
#
# Run: 229, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 9.55, max: 23)
#
# Run: 230, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 9.63, max: 23)
#
# Run: 231, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 9.7, max: 23)
#
# Run: 232, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 9.81, max: 23)
#
# Run: 233, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.8, max: 23)
#
# Run: 234, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.81, max: 23)
#
# Run: 235, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 9.82, max: 23)
#
# Run: 236, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.81, max: 23)
#
# Run: 237, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.8, max: 23)
#
# Run: 238, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 9.88, max: 23)
#
# Run: 239, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 9.88, max: 23)
#
# Run: 240, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.9, max: 23)
#
# Run: 241, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 9.96, max: 23)
#
# Run: 242, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 9.99, max: 23)
#
# Run: 243, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 10.02, max: 23)
#
# Run: 244, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.06, max: 23)
#
# Run: 245, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.04, max: 23)
#
# Run: 246, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 10.09, max: 23)
#
# Run: 247, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.1, max: 23)
#
# Run: 248, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 10.37, max: 37)
#
# Run: 249, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 10.4, max: 37)
#
# Run: 250, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 10.67, max: 37)
#
# Run: 251, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 10.95, max: 37)
#
# Run: 252, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.06, max: 37)
#
# Run: 253, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 11.21, max: 37)
#
# Run: 254, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 11.53, max: 41)
#
# Run: 255, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 11.58, max: 41)
#
# Run: 256, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.66, max: 41)
#
# Run: 257, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 11.76, max: 41)
#
# Run: 258, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.76, max: 41)
#
# Run: 259, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 11.87, max: 41)
#
# Run: 260, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.87, max: 41)
#
# Run: 261, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 11.95, max: 41)
#
# Run: 262, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 12.13, max: 41)
#
# Run: 263, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.16, max: 41)
#
# Run: 264, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.29, max: 41)
#
# Run: 265, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.3, max: 41)
#
# Run: 266, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 12.38, max: 41)
#
# Run: 267, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 12.73, max: 44)
#
# Run: 268, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.73, max: 44)
#
# Run: 269, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 12.87, max: 44)
#
# Run: 270, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 13.05, max: 44)
#
# Run: 271, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 13.29, max: 44)
#
# Run: 272, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 13.36, max: 44)
#
# Run: 273, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 13.5, max: 44)
#
# Run: 274, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 13.66, max: 44)
#
# Run: 275, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 13.83, max: 44)
#
# Run: 276, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 14.03, max: 44)
#
# Run: 277, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 14.03, max: 44)
#
# Run: 278, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.22, max: 44)
#
# Run: 279, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 14.47, max: 44)
#
# Run: 280, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.5, max: 44)
#
# Run: 281, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 14.67, max: 44)
#
# Run: 282, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 14.7, max: 44)
#
# Run: 283, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 14.76, max: 44)
#
# Run: 284, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 14.85, max: 44)
#
# Run: 285, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.93, max: 44)
#
# Run: 286, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.09, max: 44)
#
# Run: 287, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.13, max: 44)
#
# Run: 288, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 15.41, max: 44)
#
# Run: 289, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.47, max: 44)
#
# Run: 290, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.49, max: 44)
#
# Run: 291, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.62, max: 44)
#
# Run: 292, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.69, max: 44)
#
# Run: 293, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 16.06, max: 46)
#
# Run: 294, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 16.22, max: 46)
#
# Run: 295, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 16.35, max: 46)
#
# Run: 296, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 16.46, max: 46)
#
# Run: 297, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.59, max: 46)
#
# Run: 298, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.64, max: 46)
#
# Run: 299, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.66, max: 46)
#
# Run: 300, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.66, max: 46)
#
# Run: 301, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 16.98, max: 46)
#
# Run: 302, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 17.05, max: 46)
#
# Run: 303, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 17.44, max: 48)
#
# Run: 304, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 17.62, max: 48)
# Run: 305, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 17.7, max: 48)
#
# Run: 306, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 17.71, max: 48)
#
# Run: 307, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 17.77, max: 48)
#
# Run: 308, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 18.05, max: 48)
#
# Run: 309, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 18.07, max: 48)
#
# Run: 310, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 18.49, max: 50)
#
# Run: 311, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 18.93, max: 54)
#
# Run: 312, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19, max: 54)
#
# Run: 313, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 19.21, max: 54)
#
# Run: 314, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 19.66, max: 54)
#
# Run: 315, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 19.79, max: 54)
#
# Run: 316, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 19.83, max: 54)
#
# Run: 317, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.98, max: 54)
#
# Run: 318, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 19.96, max: 54)
#
# Run: 319, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.98, max: 54)
#
# Run: 320, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 20.05, max: 54)
#
# Run: 321, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 20.56, max: 61)
#
# Run: 322, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 20.6, max: 61)
#
# Run: 323, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 20.82, max: 61)
#
# Run: 324, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 21.05, max: 61)
#
# Run: 325, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 21.04, max: 61)
#
# Run: 326, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 21.11, max: 61)
#
# Run: 327, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 21.3, max: 61)
#
# Run: 328, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 21.44, max: 61)
#
# Run: 329, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 21.67, max: 61)
#
# Run: 330, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 21.86, max: 61)
#
# Run: 331, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 21.92, max: 61)
#
# Run: 332, exploration: 0.01, score: 56
# Scores: (min: 9, avg: 22.29, max: 61)
#
# Run: 333, exploration: 0.01, score: 54
# Scores: (min: 9, avg: 22.74, max: 61)
#
# Run: 334, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 23.08, max: 61)
#
# Run: 335, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 23.25, max: 61)
#
# Run: 336, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 23.32, max: 61)
#
# Run: 337, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 23.47, max: 61)
#
# Run: 338, exploration: 0.01, score: 47
# Scores: (min: 9, avg: 23.76, max: 61)
#
# Run: 339, exploration: 0.01, score: 32
# Scores: (min: 9, avg: 23.99, max: 61)
#
# Run: 340, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 24.24, max: 61)
#
# Run: 341, exploration: 0.01, score: 78
# Scores: (min: 9, avg: 24.87, max: 78)
#
# Run: 342, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 25.1, max: 78)
#
# Run: 343, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 25.37, max: 78)
#
# Run: 344, exploration: 0.01, score: 54
# Scores: (min: 9, avg: 25.77, max: 78)
#
# Run: 345, exploration: 0.01, score: 42
# Scores: (min: 9, avg: 26.1, max: 78)
#
# Run: 346, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 26.08, max: 78)
#
# Run: 347, exploration: 0.01, score: 36
# Scores: (min: 9, avg: 26.34, max: 78)
#
# Run: 348, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 26.37, max: 78)
#
# Run: 349, exploration: 0.01, score: 30
# Scores: (min: 9, avg: 26.55, max: 78)
#
# Run: 350, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 26.46, max: 78)
#
# Run: 351, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 26.91, max: 82)
#
# Run: 352, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 27.29, max: 82)
#
# Run: 353, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 27.27, max: 82)
#
# Run: 354, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 26.97, max: 82)
#
# Run: 355, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 26.97, max: 82)
#
# Run: 356, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 26.91, max: 82)
#
# Run: 357, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 26.84, max: 82)
#
# Run: 358, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 27.23, max: 82)
#
# Run: 359, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 27.56, max: 82)
#
# Run: 360, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 27.8, max: 82)
#
# Run: 361, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 27.73, max: 82)
#
# Run: 362, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 27.67, max: 82)
#
# Run: 363, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 27.82, max: 82)
#
# Run: 364, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 27.74, max: 82)
#
# Run: 365, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 27.97, max: 82)
#
# Run: 366, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 28.19, max: 82)
#
# Run: 367, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 27.94, max: 82)
#
# Run: 368, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 28.12, max: 82)
#
# Run: 369, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 28.01, max: 82)
#
# Run: 370, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 28.23, max: 82)
#
# Run: 371, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 28.07, max: 82)
#
# Run: 372, exploration: 0.01, score: 63
# Scores: (min: 9, avg: 28.54, max: 82)
#
# Run: 373, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 28.83, max: 82)
#
# Run: 374, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 28.74, max: 82)
#
# Run: 375, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 28.61, max: 82)
#
# Run: 376, exploration: 0.01, score: 38
# Scores: (min: 9, avg: 28.71, max: 82)
#
# Run: 377, exploration: 0.01, score: 129
# Scores: (min: 9, avg: 29.91, max: 129)
#
# Run: 378, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 29.99, max: 129)
#
# Run: 379, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 29.86, max: 129)
#
# Run: 380, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 30.02, max: 129)
#
# Run: 381, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 29.88, max: 129)
#
# Run: 382, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 29.87, max: 129)
#
# Run: 383, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 29.82, max: 129)
#
# Run: 384, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 29.89, max: 129)
#
# Run: 385, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 29.87, max: 129)
#
# Run: 386, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 29.7, max: 129)
#
# Run: 387, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.64, max: 129)
#
# Run: 388, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.36, max: 129)
#
# Run: 389, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 29.37, max: 129)
#
# Run: 390, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 29.58, max: 129)
#
# Run: 391, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 29.45, max: 129)
#
# Run: 392, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 29.45, max: 129)
#
# Run: 393, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 29.21, max: 129)
#
# Run: 394, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 29.2, max: 129)
#
# Run: 395, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 29.12, max: 129)
#
# Run: 396, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 30.03, max: 129)
#
# Run: 397, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 30.02, max: 129)
#
# Run: 398, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 29.95, max: 129)
#
# Run: 399, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.93, max: 129)
#
# Run: 400, exploration: 0.01, score: 89
# Scores: (min: 8, avg: 30.72, max: 129)
#
# Run: 401, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 30.58, max: 129)
#
# Run: 402, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 30.75, max: 129)
#
# Run: 403, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.39, max: 129)
#
# Run: 404, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.21, max: 129)
#
# Run: 405, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 30.37, max: 129)
#
# Run: 406, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 30.79, max: 129)
#
# Run: 407, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 30.87, max: 129)
#
# Run: 408, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 30.68, max: 129)
#
# Run: 409, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.67, max: 129)
# Run: 410, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 30.63, max: 129)
#
# Run: 411, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.24, max: 129)
#
# Run: 412, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 30.41, max: 129)
#
# Run: 413, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 30.27, max: 129)
#
# Run: 414, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 29.87, max: 129)
#
# Run: 415, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 29.95, max: 129)
#
# Run: 416, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 29.85, max: 129)
#
# Run: 417, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 30.8, max: 129)
#
# Run: 418, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 30.95, max: 129)
#
# Run: 419, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 30.97, max: 129)
#
# Run: 420, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.91, max: 129)
#
# Run: 421, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.39, max: 129)
#
# Run: 422, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 30.8, max: 129)
#
# Run: 423, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 30.66, max: 129)
#
# Run: 424, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 30.44, max: 129)
#
# Run: 425, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 30.7, max: 129)
#
# Run: 426, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 30.73, max: 129)
#
# Run: 427, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 30.8, max: 129)
#
# Run: 428, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 30.82, max: 129)
#
# Run: 429, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 31.27, max: 129)
#
# Run: 430, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 31.14, max: 129)
#
# Run: 431, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 31.45, max: 129)
#
# Run: 432, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 31.36, max: 129)
#
# Run: 433, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 30.95, max: 129)
#
# Run: 434, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.6, max: 129)
#
# Run: 435, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 30.42, max: 129)
#
# Run: 436, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 30.37, max: 129)
#
# Run: 437, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 30.27, max: 129)
#
# Run: 438, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 30.41, max: 129)
#
# Run: 439, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 30.36, max: 129)
#
# Run: 440, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 30.15, max: 129)
#
# Run: 441, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 29.86, max: 129)
#
# Run: 442, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 30.3, max: 129)
#
# Run: 443, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 31.35, max: 145)
#
# Run: 444, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 31.61, max: 145)
#
# Run: 445, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 31.48, max: 145)
#
# Run: 446, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 32.1, max: 145)
#
# Run: 447, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 32.36, max: 145)
#
# Run: 448, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 32.07, max: 145)
#
# Run: 449, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 32.04, max: 145)
#
# Run: 450, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 31.99, max: 145)
#
# Run: 451, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 31.51, max: 145)
#
# Run: 452, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 31.23, max: 145)
#
# Run: 453, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 31.3, max: 145)
#
# Run: 454, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.29, max: 145)
#
# Run: 455, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 31.31, max: 145)
#
# Run: 456, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 31.31, max: 145)
#
# Run: 457, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 31.29, max: 145)
#
# Run: 458, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 30.9, max: 145)
#
# Run: 459, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 30.63, max: 145)
#
# Run: 460, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 30.44, max: 145)
#
# Run: 461, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 30.74, max: 145)
#
# Run: 462, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 31.42, max: 145)
#
# Run: 463, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 31.38, max: 145)
#
# Run: 464, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 31.49, max: 145)
#
# Run: 465, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 31.6, max: 145)
#
# Run: 466, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 31.65, max: 145)
#
# Run: 467, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 32.57, max: 145)
#
# Run: 468, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 32.75, max: 145)
#
# Run: 469, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 32.83, max: 145)
#
# Run: 470, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 32.9, max: 145)
#
# Run: 471, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 33.22, max: 145)
#
# Run: 472, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 32.72, max: 145)
#
# Run: 473, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 32.48, max: 145)
#
# Run: 474, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 32.59, max: 145)
#
# Run: 475, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 32.56, max: 145)
#
# Run: 476, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 32.64, max: 145)
#
# Run: 477, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 31.71, max: 145)
#
# Run: 478, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 31.45, max: 145)
#
# Run: 479, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 31.74, max: 145)
#
# Run: 480, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 32.07, max: 145)
#
# Run: 481, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 32.56, max: 145)
#
# Run: 482, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 32.74, max: 145)
#
# Run: 483, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 33.11, max: 145)
#
# Run: 484, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 33.14, max: 145)
#
# Run: 485, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 33.29, max: 145)
#
# Run: 486, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 33.77, max: 145)
#
# Run: 487, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 34.02, max: 145)
#
# Run: 488, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 34.37, max: 145)
#
# Run: 489, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 35.43, max: 145)
#
# Run: 490, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 35.49, max: 145)
#
# Run: 491, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 35.64, max: 145)
#
# Run: 492, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 35.83, max: 145)
#
# Run: 493, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 36.28, max: 145)
#
# Run: 494, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 36.16, max: 145)
#
# Run: 495, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 36.78, max: 145)
#
# Run: 496, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 36.23, max: 145)
#
# Run: 497, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 36.9, max: 145)
#
# Run: 498, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 37.34, max: 145)
#
# Run: 499, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 37.6, max: 145)
#
# Run: 500, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 36.81, max: 145)
#
# Run: 501, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 36.86, max: 145)
#
# Run: 502, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 36.95, max: 145)
#
# Run: 503, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 37.57, max: 145)
#
# Run: 504, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 37.56, max: 145)
#
# Run: 505, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 37.33, max: 145)
#
# Run: 506, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 36.97, max: 145)
#
# Run: 507, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 36.92, max: 145)
#
# Run: 508, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 36.87, max: 145)
#
# Run: 509, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 37.16, max: 145)
#
# Run: 510, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 36.81, max: 145)
#
# Run: 511, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 36.74, max: 145)
#
# Run: 512, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 37.06, max: 145)
#
# Run: 513, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 37.14, max: 145)
# Run: 514, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 37.86, max: 145)
#
# Run: 515, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 37.7, max: 145)
#
# Run: 516, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 38.28, max: 145)
#
# Run: 517, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 37.4, max: 145)
#
# Run: 518, exploration: 0.01, score: 68
# Scores: (min: 8, avg: 37.84, max: 145)
#
# Run: 519, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 38.57, max: 145)
#
# Run: 520, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 38.78, max: 145)
#
# Run: 521, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 39, max: 145)
#
# Run: 522, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 38.73, max: 145)
#
# Run: 523, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 39.05, max: 145)
#
# Run: 524, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 39.25, max: 145)
#
# Run: 525, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 39.09, max: 145)
#
# Run: 526, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 39.05, max: 145)
#
# Run: 527, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 38.86, max: 145)
#
# Run: 528, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 38.82, max: 145)
#
# Run: 529, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 38.47, max: 145)
#
# Run: 530, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 38.52, max: 145)
#
# Run: 531, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 38.13, max: 145)
#
# Run: 532, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 38.39, max: 145)
#
# Run: 533, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 38.69, max: 145)
#
# Run: 534, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 39.68, max: 145)
#
# Run: 535, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 39.82, max: 145)
#
# Run: 536, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 39.97, max: 145)
#
# Run: 537, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 40.97, max: 145)
#
# Run: 538, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 40.65, max: 145)
#
# Run: 539, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 40.61, max: 145)
#
# Run: 540, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 40.79, max: 145)
#
# Run: 541, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 40.43, max: 145)
#
# Run: 542, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 39.76, max: 145)
#
# Run: 543, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 38.42, max: 122)
#
# Run: 544, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 37.84, max: 122)
#
# Run: 545, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 37.67, max: 122)
#
# Run: 546, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 37.23, max: 122)
#
# Run: 547, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 36.78, max: 122)
#
# Run: 548, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 37.21, max: 122)
#
# Run: 549, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 37.48, max: 122)
#
# Run: 550, exploration: 0.01, score: 121
# Scores: (min: 8, avg: 38.46, max: 122)
#
# Run: 551, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 38.63, max: 122)
#
# Run: 552, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 38.59, max: 122)
#
# Run: 553, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 39.03, max: 122)
#
# Run: 554, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 39.19, max: 122)
#
# Run: 555, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 39.26, max: 122)
#
# Run: 556, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 39.25, max: 122)
#
# Run: 557, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 40.4, max: 125)
#
# Run: 558, exploration: 0.01, score: 102
# Scores: (min: 8, avg: 41.32, max: 125)
#
# Run: 559, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 41.31, max: 125)
#
# Run: 560, exploration: 0.01, score: 113
# Scores: (min: 8, avg: 42.3, max: 125)
#
# Run: 561, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 42.02, max: 125)
#
# Run: 562, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 41.45, max: 125)
#
# Run: 563, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 41.5, max: 125)
#
# Run: 564, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 41.34, max: 125)
#
# Run: 565, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 41.61, max: 125)
#
# Run: 566, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 41.35, max: 125)
#
# Run: 567, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 40.9, max: 125)
#
# Run: 568, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 40.8, max: 125)
#
# Run: 569, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 40.72, max: 125)
#
# Run: 570, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 40.35, max: 125)
#
# Run: 571, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 40.31, max: 125)
#
# Run: 572, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 40.35, max: 125)
#
# Run: 573, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 40.18, max: 125)
#
# Run: 574, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 40.12, max: 125)
#
# Run: 575, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 40.31, max: 125)
#
# Run: 576, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 40.83, max: 125)
#
# Run: 577, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 40.77, max: 125)
#
# Run: 578, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 40.86, max: 125)
#
# Run: 579, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 40.62, max: 125)
#
# Run: 580, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 40.2, max: 125)
#
# Run: 581, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 40.51, max: 125)
#
# Run: 582, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 40.58, max: 125)
#
# Run: 583, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 40.6, max: 125)
#
# Run: 584, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 40.77, max: 125)
#
# Run: 585, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 40.72, max: 125)
#
# Run: 586, exploration: 0.01, score: 107
# Scores: (min: 8, avg: 41.23, max: 125)
#
# Run: 587, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 41.43, max: 125)
#
# Run: 588, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 41.95, max: 125)
#
# Run: 589, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 41.36, max: 125)
#
# Run: 590, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 41.08, max: 125)
#
# Run: 591, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 40.92, max: 125)
#
# Run: 592, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 40.64, max: 125)
#
# Run: 593, exploration: 0.01, score: 140
# Scores: (min: 8, avg: 41.37, max: 140)
#
# Run: 594, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 41.5, max: 140)
#
# Run: 595, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 41.56, max: 140)
#
# Run: 596, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 41.82, max: 140)
#
# Run: 597, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 41.05, max: 140)
#
# Run: 598, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 41.09, max: 140)
#
# Run: 599, exploration: 0.01, score: 78
# Scores: (min: 8, avg: 41.52, max: 140)
#
# Run: 600, exploration: 0.01, score: 78
# ...
#
# Run: 1050, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 145.53, max: 436)
#
# Run: 1051, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 145.93, max: 436)
#
# Run: 1052, exploration: 0.01, score: 71
# Scores: (min: 9, avg: 146.51, max: 436)
#
# Run: 1053, exploration: 0.01, score: 87
# Scores: (min: 9, avg: 147.24, max: 436)
#
# Run: 1054, exploration: 0.01, score: 147
# Scores: (min: 9, avg: 148.6, max: 436)
#
# Run: 1055, exploration: 0.01, score: 58
# Scores: (min: 11, avg: 149.09, max: 436)
#
# Run: 1056, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 150.09, max: 436)
#
# Run: 1057, exploration: 0.01, score: 22
# Scores: (min: 11, avg: 150.19, max: 436)
#
# Run: 1058, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 151.05, max: 436)
#
# Run: 1059, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 152.35, max: 436)
#
# Run: 1060, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 153.17, max: 436)
#
# Run: 1061, exploration: 0.01, score: 150
# Scores: (min: 11, avg: 154.54, max: 436)
#
# Run: 1062, exploration: 0.01, score: 84
# Scores: (min: 15, avg: 155.27, max: 436)
#
# Run: 1063, exploration: 0.01, score: 182
# Scores: (min: 21, avg: 156.94, max: 436)
#
# Run: 1064, exploration: 0.01, score: 104
# Scores: (min: 21, avg: 157.65, max: 436)
#
# Run: 1065, exploration: 0.01, score: 105
# Scores: (min: 21, avg: 156.68, max: 436)
#
# Run: 1066, exploration: 0.01, score: 102
# Scores: (min: 21, avg: 154.29, max: 436)
#
# Run: 1067, exploration: 0.01, score: 293
# Scores: (min: 21, avg: 155.68, max: 436)
#
# Run: 1068, exploration: 0.01, score: 169
# Scores: (min: 21, avg: 155.7, max: 436)
#
# Run: 1069, exploration: 0.01, score: 130
# Scores: (min: 21, avg: 154.86, max: 436)
#
# Run: 1070, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 153.78, max: 436)
#
# Run: 1071, exploration: 0.01, score: 343
# Scores: (min: 9, avg: 155.34, max: 436)
#
# Run: 1072, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 153.52, max: 436)
#
# Run: 1073, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 152.06, max: 436)
#
# Run: 1074, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 151.37, max: 436)
#
# Run: 1075, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 154.4, max: 500)
#
# Run: 1076, exploration: 0.01, score: 139
# Scores: (min: 9, avg: 154.52, max: 500)
#
# Run: 1077, exploration: 0.01, score: 87
# Scores: (min: 9, avg: 154.24, max: 500)
#
# Run: 1078, exploration: 0.01, score: 79
# Scores: (min: 9, avg: 152.52, max: 500)
#
# Run: 1079, exploration: 0.01, score: 85
# Scores: (min: 9, avg: 152.53, max: 500)
#
# Run: 1080, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 152.16, max: 500)
#
# Run: 1081, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 151.78, max: 500)
#
# Run: 1082, exploration: 0.01, score: 261
# Scores: (min: 9, avg: 153.16, max: 500)
#
# Run: 1083, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 152.63, max: 500)
#
# Run: 1084, exploration: 0.01, score: 279
# Scores: (min: 9, avg: 153.84, max: 500)
#
# Run: 1085, exploration: 0.01, score: 317
# Scores: (min: 9, avg: 155.53, max: 500)
#
# Run: 1086, exploration: 0.01, score: 274
# Scores: (min: 9, avg: 156.3, max: 500)
#
# Run: 1087, exploration: 0.01, score: 412
# Scores: (min: 9, avg: 158.59, max: 500)
#
# Run: 1088, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 158.09, max: 500)
#
# Run: 1089, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 157.08, max: 500)
#
# Run: 1090, exploration: 0.01, score: 24
# Scores: (min: 9, avg: 155.11, max: 500)
#
# Run: 1091, exploration: 0.01, score: 72
# Scores: (min: 9, avg: 154.41, max: 500)
#
# Run: 1092, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 152.76, max: 500)
#
# Run: 1093, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 151.41, max: 500)
#
# Run: 1094, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 149.89, max: 500)
#
# Run: 1095, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 149.2, max: 500)
#
# Run: 1096, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 149.36, max: 500)
#
# Run: 1097, exploration: 0.01, score: 90
# Scores: (min: 9, avg: 149.78, max: 500)
#
# Run: 1098, exploration: 0.01, score: 137
# Scores: (min: 9, avg: 150.09, max: 500)
#
# Run: 1099, exploration: 0.01, score: 123
# Scores: (min: 9, avg: 149.2, max: 500)
#
# Run: 1100, exploration: 0.01, score: 94
# Scores: (min: 9, avg: 146.73, max: 500)
#
# Run: 1101, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 146.27, max: 500)
#
# Run: 1102, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 146.5, max: 500)
#
# Run: 1103, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 145.44, max: 500)
#
# Run: 1104, exploration: 0.01, score: 82
# Scores: (min: 9, avg: 144.18, max: 500)
#
# Run: 1105, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 144.11, max: 500)
#
# Run: 1106, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 141.45, max: 500)
#
# Run: 1107, exploration: 0.01, score: 27
# Scores: (min: 9, avg: 139.86, max: 500)
#
# Run: 1108, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 137.26, max: 500)
#
# Run: 1109, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 134.57, max: 500)
#
# Run: 1110, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 133.57, max: 500)
#
# Run: 1111, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 132.62, max: 500)
#
# Run: 1112, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 131.03, max: 500)
#
# Run: 1113, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 129.98, max: 500)
#
# Run: 1114, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 128.83, max: 500)
#
# Run: 1115, exploration: 0.01, score: 45
# Scores: (min: 9, avg: 129, max: 500)
#
# Run: 1116, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 129.1, max: 500)
#
# Run: 1117, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 130.09, max: 500)
#
# Run: 1118, exploration: 0.01, score: 284
# Scores: (min: 9, avg: 129.5, max: 500)
#
# Run: 1119, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 127.83, max: 500)
#
# Run: 1120, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 127.91, max: 500)
#
# Run: 1121, exploration: 0.01, score: 263
# Scores: (min: 9, avg: 128.29, max: 500)
#
# Run: 1122, exploration: 0.01, score: 156
# Scores: (min: 9, avg: 127.73, max: 500)
#
# Run: 1123, exploration: 0.01, score: 50
# Scores: (min: 9, avg: 126.41, max: 500)
#
# Run: 1124, exploration: 0.01, score: 28
# Scores: (min: 9, avg: 125.57, max: 500)
#
# Run: 1125, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 122.93, max: 500)
#
# Run: 1126, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 121.79, max: 500)
#
# Run: 1127, exploration: 0.01, score: 68
# Scores: (min: 9, avg: 120.73, max: 500)
#
# Run: 1128, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 121.08, max: 500)
#
# Run: 1129, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 121.61, max: 500)
# Run: 1130, exploration: 0.01, score: 74
# Scores: (min: 9, avg: 121.45, max: 500)
#
# Run: 1131, exploration: 0.01, score: 39
# Scores: (min: 9, avg: 121.01, max: 500)
#
# Run: 1132, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 119.6, max: 500)
#
# Run: 1133, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 115.34, max: 500)
#
# Run: 1134, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 113.1, max: 500)
#
# Run: 1135, exploration: 0.01, score: 184
# Scores: (min: 9, avg: 114.19, max: 500)
#
# Run: 1136, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 114.24, max: 500)
#
# Run: 1137, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 112.84, max: 500)
#
# Run: 1138, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 111.51, max: 500)
#
# Run: 1139, exploration: 0.01, score: 40
# Scores: (min: 9, avg: 110.13, max: 500)
#
# Run: 1140, exploration: 0.01, score: 44
# Scores: (min: 9, avg: 109.52, max: 500)
#
# Run: 1141, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 109.13, max: 500)
#
# Run: 1142, exploration: 0.01, score: 66
# Scores: (min: 9, avg: 108.86, max: 500)
#
# Run: 1143, exploration: 0.01, score: 84
# Scores: (min: 9, avg: 105.64, max: 500)
#
# Run: 1144, exploration: 0.01, score: 52
# Scores: (min: 9, avg: 103.7, max: 500)
#
# Run: 1145, exploration: 0.01, score: 93
# Scores: (min: 9, avg: 102.85, max: 500)
#
# Run: 1146, exploration: 0.01, score: 53
# Scores: (min: 9, avg: 102.01, max: 500)
#
# Run: 1147, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 101.2, max: 500)
#
# Run: 1148, exploration: 0.01, score: 283
# Scores: (min: 9, avg: 103.15, max: 500)
#
# Run: 1149, exploration: 0.01, score: 161
# Scores: (min: 9, avg: 103.73, max: 500)
#
# Run: 1150, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 103.7, max: 500)
#
# Run: 1151, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 104.65, max: 500)
#
# Run: 1152, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 105.56, max: 500)
#
# Run: 1153, exploration: 0.01, score: 190
# Scores: (min: 9, avg: 106.59, max: 500)
#
# Run: 1154, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 105.47, max: 500)
#
# Run: 1155, exploration: 0.01, score: 26
# Scores: (min: 9, avg: 105.15, max: 500)
#
# Run: 1156, exploration: 0.01, score: 29
# Scores: (min: 9, avg: 104.33, max: 500)
#
# Run: 1157, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 104.31, max: 500)
#
# Run: 1158, exploration: 0.01, score: 31
# Scores: (min: 9, avg: 103.64, max: 500)
#
# Run: 1159, exploration: 0.01, score: 165
# Scores: (min: 9, avg: 103.83, max: 500)
#
# Run: 1160, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 103.96, max: 500)
#
# Run: 1161, exploration: 0.01, score: 57
# Scores: (min: 9, avg: 103.03, max: 500)
#
# Run: 1162, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 103.24, max: 500)
#
# Run: 1163, exploration: 0.01, score: 61
# Scores: (min: 9, avg: 102.03, max: 500)
#
# Run: 1164, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 103.23, max: 500)
#
# Run: 1165, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 103.17, max: 500)
#
# Run: 1166, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 103.14, max: 500)
#
# Run: 1167, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 101.22, max: 500)
#
# Run: 1168, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 100.75, max: 500)
#
# Run: 1169, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 100.58, max: 500)
#
# Run: 1170, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 101.68, max: 500)
#
# Run: 1171, exploration: 0.01, score: 118
# Scores: (min: 9, avg: 99.43, max: 500)
#
# Run: 1172, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 100.37, max: 500)
#
# Run: 1173, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 101.22, max: 500)
#
# Run: 1174, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 101.95, max: 500)
#
# Run: 1175, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 98.04, max: 412)
#
# Run: 1176, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 98.1, max: 412)
#
# Run: 1177, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 98.22, max: 412)
#
# Run: 1178, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 98.4, max: 412)
#
# Run: 1179, exploration: 0.01, score: 101
# Scores: (min: 9, avg: 98.56, max: 412)
#
# Run: 1180, exploration: 0.01, score: 98
# Scores: (min: 9, avg: 98.43, max: 412)
#
# Run: 1181, exploration: 0.01, score: 89
# Scores: (min: 9, avg: 98.19, max: 412)
#
# Run: 1182, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 96.58, max: 412)
#
# Run: 1183, exploration: 0.01, score: 142
# Scores: (min: 9, avg: 97.26, max: 412)
#
# Run: 1184, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 95.98, max: 412)
#
# Run: 1185, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 94.56, max: 412)
#
# Run: 1186, exploration: 0.01, score: 70
# Scores: (min: 9, avg: 92.52, max: 412)
#
# Run: 1187, exploration: 0.01, score: 33
# Scores: (min: 9, avg: 88.73, max: 284)
#
# Run: 1188, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 89.27, max: 284)
#
# Run: 1189, exploration: 0.01, score: 201
# Scores: (min: 9, avg: 91.07, max: 284)
#
# Run: 1190, exploration: 0.01, score: 99
# Scores: (min: 9, avg: 91.82, max: 284)
#
# Run: 1191, exploration: 0.01, score: 109
# Scores: (min: 9, avg: 92.19, max: 284)
#
# Run: 1192, exploration: 0.01, score: 235
# Scores: (min: 9, avg: 93.36, max: 284)
#
# Run: 1193, exploration: 0.01, score: 150
# Scores: (min: 9, avg: 94.75, max: 284)
#
# Run: 1194, exploration: 0.01, score: 104
# Scores: (min: 9, avg: 95.68, max: 284)
#
# Run: 1195, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 96, max: 284)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-42e4c8d66b82> in <module>
# ----> 1 cartpole() # Changed learning rate to 0.004
#
# <ipython-input-13-1658d8d3fa35> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#
# <ipython-input-13-1658d8d3fa35> in experience_replay(self)
#      53             q_update = reward
#      54             if not terminal:
# ---> 55                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
cartpole() # Changed exploration decay to 0.905
           # Solved in 243 runs, 343 runs total
# Out:
# Run: 1, exploration: 0.08245452233512682, score: 45
# Scores: (min: 45, avg: 45, max: 45)
#
# Run: 2, exploration: 0.03710249487545281, score: 9
# Scores: (min: 9, avg: 27, max: 45)
#
# Run: 3, exploration: 0.015109160222299656, score: 10
# Scores: (min: 9, avg: 21.333333333333332, max: 45)
#
# Run: 4, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18, max: 45)
#
# Run: 5, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 16.4, max: 45)
#
# Run: 6, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 15.166666666666666, max: 45)
#
# Run: 7, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 14.428571428571429, max: 45)
#
# Run: 8, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14, max: 45)
#
# Run: 9, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 13.444444444444445, max: 45)
#
# Run: 10, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.3, max: 45)
#
# Run: 11, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 13.272727272727273, max: 45)
#
# Run: 12, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 13.416666666666666, max: 45)
#
# Run: 13, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 13.307692307692308, max: 45)
#
# Run: 14, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 13.642857142857142, max: 45)
#
# Run: 15, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 13.666666666666666, max: 45)
#
# Run: 16, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 14.625, max: 45)
#
# Run: 17, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 15.882352941176471, max: 45)
#
# Run: 18, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 16.22222222222222, max: 45)
#
# Run: 19, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 16.36842105263158, max: 45)
#
# Run: 20, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 16.85, max: 45)
#
# Run: 21, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.761904761904763, max: 45)
#
# Run: 22, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.681818181818183, max: 45)
#
# Run: 23, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.73913043478261, max: 45)
#
# Run: 24, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 18.666666666666668, max: 63)
#
# Run: 25, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 18.96, max: 63)
#
# Run: 26, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19, max: 63)
#
# Run: 27, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 19.85185185185185, max: 63)
#
# Run: 28, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 20.892857142857142, max: 63)
#
# Run: 29, exploration: 0.01, score: 69
# Scores: (min: 8, avg: 22.551724137931036, max: 69)
#
# Run: 30, exploration: 0.01, score: 108
# Scores: (min: 8, avg: 25.4, max: 108)
#
# Run: 31, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 28, max: 108)
#
# Run: 32, exploration: 0.01, score: 150
# Scores: (min: 8, avg: 31.8125, max: 150)
#
# Run: 33, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 35.90909090909091, max: 167)
#
# Run: 34, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 41.205882352941174, max: 216)
#
# Run: 35, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 46, max: 216)
#
# Run: 36, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 50.30555555555556, max: 216)
#
# Run: 37, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 55.189189189189186, max: 231)
#
# Run: 38, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 60.3421052631579, max: 251)
#
# Run: 39, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 64.84615384615384, max: 251)
#
# Run: 40, exploration: 0.01, score: 354
# Scores: (min: 8, avg: 72.075, max: 354)
#
# Run: 41, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 74.21951219512195, max: 354)
#
# Run: 42, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 77.80952380952381, max: 354)
#
# Run: 43, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 80.27906976744185, max: 354)
#
# Run: 44, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 84.29545454545455, max: 354)
#
# Run: 45, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 86.93333333333334, max: 354)
#
# Run: 46, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 90.5, max: 354)
#
# Run: 47, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 92.74468085106383, max: 354)
#
# Run: 48, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 95.14583333333333, max: 354)
#
# Run: 49, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 97.14285714285714, max: 354)
#
# Run: 50, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 98.98, max: 354)
#
# Run: 51, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 101.56862745098039, max: 354)
#
# Run: 52, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 103.28846153846153, max: 354)
#
# Run: 53, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 104.77358490566037, max: 354)
#
# Run: 54, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 106, max: 354)
#
# Run: 55, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 107.72727272727273, max: 354)
#
# Run: 56, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 108.80357142857143, max: 354)
#
# Run: 57, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 110.98245614035088, max: 354)
#
# Run: 58, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 112.72413793103448, max: 354)
#
# Run: 59, exploration: 0.01, score: 191
# Scores: (min: 8, avg: 114.05084745762711, max: 354)
#
# Run: 60, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 115.68333333333334, max: 354)
#
# Run: 61, exploration: 0.01, score: 136
# Scores: (min: 8, avg: 116.01639344262296, max: 354)
#
# Run: 62, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 117.1774193548387, max: 354)
#
# Run: 63, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 118.63492063492063, max: 354)
#
# Run: 64, exploration: 0.01, score: 154
# Scores: (min: 8, avg: 119.1875, max: 354)
#
# Run: 65, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 120.81538461538462, max: 354)
#
# Run: 66, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 122.07575757575758, max: 354)
#
# Run: 67, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 123.70149253731343, max: 354)
#
# Run: 68, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 125.19117647058823, max: 354)
#
# Run: 69, exploration: 0.01, score: 156
# Scores: (min: 8, avg: 125.6376811594203, max: 354)
#
# Run: 70, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 126.75714285714285, max: 354)
#
# Run: 71, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 127.98591549295774, max: 354)
#
# Run: 72, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 128.61111111111111, max: 354)
#
# Run: 73, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 129.5068493150685, max: 354)
#
# Run: 74, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 130.2027027027027, max: 354)
#
# Run: 75, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 131.64, max: 354)
#
# Run: 76, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 131.94736842105263, max: 354)
#
# Run: 77, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 133, max: 354)
#
# Run: 78, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 133.56410256410257, max: 354)
#
# Run: 79, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 133.62025316455697, max: 354)
#
# Run: 80, exploration: 0.01, score: 138
# Scores: (min: 8, avg: 133.675, max: 354)
#
# Run: 81, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 134.0493827160494, max: 354)
#
# Run: 82, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 134.82926829268294, max: 354)
#
# Run: 83, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 135.90361445783134, max: 354)
#
# Run: 84, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 136.27380952380952, max: 354)
#
# Run: 85, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 136.3764705882353, max: 354)
#
# Run: 86, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 135.95348837209303, max: 354)
#
# Run: 87, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 136.2183908045977, max: 354)
#
# Run: 88, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 136.02272727272728, max: 354)
#
# Run: 89, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 136.37078651685394, max: 354)
#
# Run: 90, exploration: 0.01, score: 137
# Scores: (min: 8, avg: 136.37777777777777, max: 354)
#
# Run: 91, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 136.8021978021978, max: 354)
#
# Run: 92, exploration: 0.01, score: 98
# Scores: (min: 8, avg: 136.3804347826087, max: 354)
#
# Run: 93, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 137.25806451612902, max: 354)
# Run: 94, exploration: 0.01, score: 144
# Scores: (min: 8, avg: 137.32978723404256, max: 354)
#
# Run: 95, exploration: 0.01, score: 124
# Scores: (min: 8, avg: 137.18947368421053, max: 354)
#
# Run: 96, exploration: 0.01, score: 286
# Scores: (min: 8, avg: 138.73958333333334, max: 354)
#
# Run: 97, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 138.340206185567, max: 354)
#
# Run: 98, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 137.9387755102041, max: 354)
#
# Run: 99, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 138.78787878787878, max: 354)
#
# Run: 100, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 139.28, max: 354)
#
# Run: 101, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 141.04, max: 354)
#
# Run: 102, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 142.5, max: 354)
#
# Run: 103, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 144.63, max: 354)
#
# Run: 104, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 146.48, max: 354)
#
# Run: 105, exploration: 0.01, score: 80
# Scores: (min: 9, avg: 147.18, max: 354)
#
# Run: 106, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 149.13, max: 354)
#
# Run: 107, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 150.83, max: 354)
#
# Run: 108, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 151.86, max: 354)
#
# Run: 109, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 153.45, max: 354)
#
# Run: 110, exploration: 0.01, score: 196
# Scores: (min: 12, avg: 155.29, max: 354)
#
# Run: 111, exploration: 0.01, score: 162
# Scores: (min: 12, avg: 156.78, max: 354)
#
# Run: 112, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 158, max: 354)
#
# Run: 113, exploration: 0.01, score: 169
# Scores: (min: 14, avg: 159.57, max: 354)
#
# Run: 114, exploration: 0.01, score: 167
# Scores: (min: 14, avg: 161.06, max: 354)
#
# Run: 115, exploration: 0.01, score: 163
# Scores: (min: 15, avg: 162.55, max: 354)
#
# Run: 116, exploration: 0.01, score: 68
# Scores: (min: 15, avg: 162.94, max: 354)
#
# Run: 117, exploration: 0.01, score: 185
# Scores: (min: 15, avg: 164.43, max: 354)
#
# Run: 118, exploration: 0.01, score: 241
# Scores: (min: 15, avg: 166.62, max: 354)
#
# Run: 119, exploration: 0.01, score: 302
# Scores: (min: 15, avg: 169.45, max: 354)
#
# Run: 120, exploration: 0.01, score: 123
# Scores: (min: 15, avg: 170.42, max: 354)
#
# Run: 121, exploration: 0.01, score: 248
# Scores: (min: 15, avg: 172.75, max: 354)
#
# Run: 122, exploration: 0.01, score: 103
# Scores: (min: 18, avg: 173.63, max: 354)
#
# Run: 123, exploration: 0.01, score: 145
# Scores: (min: 20, avg: 174.9, max: 354)
#
# Run: 124, exploration: 0.01, score: 44
# Scores: (min: 20, avg: 174.71, max: 354)
#
# Run: 125, exploration: 0.01, score: 188
# Scores: (min: 20, avg: 176.33, max: 354)
#
# Run: 126, exploration: 0.01, score: 171
# Scores: (min: 42, avg: 177.84, max: 354)
#
# Run: 127, exploration: 0.01, score: 153
# Scores: (min: 44, avg: 178.95, max: 354)
#
# Run: 128, exploration: 0.01, score: 104
# Scores: (min: 44, avg: 179.5, max: 354)
#
# Run: 129, exploration: 0.01, score: 291
# Scores: (min: 44, avg: 181.72, max: 354)
#
# Run: 130, exploration: 0.01, score: 178
# Scores: (min: 44, avg: 182.42, max: 354)
#
# Run: 131, exploration: 0.01, score: 176
# Scores: (min: 44, avg: 183.12, max: 354)
#
# Run: 132, exploration: 0.01, score: 195
# Scores: (min: 44, avg: 183.57, max: 354)
#
# Run: 133, exploration: 0.01, score: 207
# Scores: (min: 44, avg: 183.97, max: 354)
#
# Run: 134, exploration: 0.01, score: 187
# Scores: (min: 44, avg: 183.68, max: 354)
#
# Run: 135, exploration: 0.01, score: 80
# Scores: (min: 44, avg: 182.39, max: 354)
#
# Run: 136, exploration: 0.01, score: 133
# Scores: (min: 44, avg: 181.71, max: 354)
#
# Run: 137, exploration: 0.01, score: 236
# Scores: (min: 44, avg: 181.76, max: 354)
#
# Run: 138, exploration: 0.01, score: 239
# Scores: (min: 44, avg: 181.64, max: 354)
#
# Run: 139, exploration: 0.01, score: 186
# Scores: (min: 44, avg: 181.14, max: 354)
#
# Run: 140, exploration: 0.01, score: 143
# Scores: (min: 44, avg: 179.03, max: 302)
#
# Run: 141, exploration: 0.01, score: 159
# Scores: (min: 44, avg: 179.02, max: 302)
#
# Run: 142, exploration: 0.01, score: 161
# Scores: (min: 44, avg: 178.38, max: 302)
#
# Run: 143, exploration: 0.01, score: 280
# Scores: (min: 44, avg: 179.34, max: 302)
#
# Run: 144, exploration: 0.01, score: 169
# Scores: (min: 44, avg: 178.46, max: 302)
#
# Run: 145, exploration: 0.01, score: 268
# Scores: (min: 44, avg: 179.11, max: 302)
#
# Run: 146, exploration: 0.01, score: 186
# Scores: (min: 44, avg: 178.46, max: 302)
#
# Run: 147, exploration: 0.01, score: 285
# Scores: (min: 44, avg: 179.35, max: 302)
#
# Run: 148, exploration: 0.01, score: 220
# Scores: (min: 44, avg: 179.47, max: 302)
#
# Run: 149, exploration: 0.01, score: 164
# Scores: (min: 44, avg: 179.18, max: 302)
#
# Run: 150, exploration: 0.01, score: 500
# Scores: (min: 44, avg: 182.29, max: 500)
#
# Run: 151, exploration: 0.01, score: 147
# Scores: (min: 44, avg: 181.45, max: 500)
#
# Run: 152, exploration: 0.01, score: 137
# Scores: (min: 44, avg: 180.91, max: 500)
#
# Run: 153, exploration: 0.01, score: 136
# Scores: (min: 44, avg: 180.45, max: 500)
#
# Run: 154, exploration: 0.01, score: 214
# Scores: (min: 44, avg: 180.88, max: 500)
#
# Run: 155, exploration: 0.01, score: 380
# Scores: (min: 44, avg: 182.67, max: 500)
#
# Run: 156, exploration: 0.01, score: 122
# Scores: (min: 44, avg: 182.21, max: 500)
#
# Run: 157, exploration: 0.01, score: 123
# Scores: (min: 44, avg: 181.11, max: 500)
#
# Run: 158, exploration: 0.01, score: 193
# Scores: (min: 44, avg: 180.92, max: 500)
#
# Run: 159, exploration: 0.01, score: 195
# Scores: (min: 44, avg: 180.96, max: 500)
#
# Run: 160, exploration: 0.01, score: 215
# Scores: (min: 44, avg: 180.99, max: 500)
#
# Run: 161, exploration: 0.01, score: 82
# Scores: (min: 44, avg: 180.45, max: 500)
#
# Run: 162, exploration: 0.01, score: 133
# Scores: (min: 44, avg: 179.9, max: 500)
#
# Run: 163, exploration: 0.01, score: 84
# Scores: (min: 44, avg: 178.65, max: 500)
#
# Run: 164, exploration: 0.01, score: 213
# Scores: (min: 44, avg: 179.24, max: 500)
#
# Run: 165, exploration: 0.01, score: 114
# Scores: (min: 44, avg: 178.13, max: 500)
#
# Run: 166, exploration: 0.01, score: 170
# Scores: (min: 44, avg: 177.79, max: 500)
#
# Run: 167, exploration: 0.01, score: 176
# Scores: (min: 44, avg: 177.24, max: 500)
#
# Run: 168, exploration: 0.01, score: 270
# Scores: (min: 44, avg: 177.69, max: 500)
#
# Run: 169, exploration: 0.01, score: 167
# Scores: (min: 44, avg: 177.8, max: 500)
#
# Run: 170, exploration: 0.01, score: 152
# Scores: (min: 44, avg: 177.28, max: 500)
#
# Run: 171, exploration: 0.01, score: 248
# Scores: (min: 44, avg: 177.62, max: 500)
#
# Run: 172, exploration: 0.01, score: 135
# Scores: (min: 44, avg: 177.24, max: 500)
#
# Run: 173, exploration: 0.01, score: 305
# Scores: (min: 44, avg: 178.35, max: 500)
#
# Run: 174, exploration: 0.01, score: 256
# Scores: (min: 44, avg: 179.1, max: 500)
#
# Run: 175, exploration: 0.01, score: 124
# Scores: (min: 44, avg: 177.96, max: 500)
#
# Run: 176, exploration: 0.01, score: 403
# Scores: (min: 44, avg: 180.44, max: 500)
#
# Run: 177, exploration: 0.01, score: 148
# Scores: (min: 44, avg: 179.79, max: 500)
#
# Run: 178, exploration: 0.01, score: 106
# Scores: (min: 44, avg: 179.08, max: 500)
#
# Run: 179, exploration: 0.01, score: 126
# Scores: (min: 44, avg: 178.96, max: 500)
#
# Run: 180, exploration: 0.01, score: 197
# Scores: (min: 44, avg: 179.55, max: 500)
#
# Run: 181, exploration: 0.01, score: 155
# Scores: (min: 44, avg: 179.46, max: 500)
#
# Run: 182, exploration: 0.01, score: 95
# Scores: (min: 44, avg: 178.43, max: 500)
#
# Run: 183, exploration: 0.01, score: 116
# Scores: (min: 44, avg: 177.35, max: 500)
#
# Run: 184, exploration: 0.01, score: 172
# Scores: (min: 44, avg: 177.4, max: 500)
#
# Run: 185, exploration: 0.01, score: 164
# Scores: (min: 44, avg: 177.59, max: 500)
#
# Run: 186, exploration: 0.01, score: 140
# Scores: (min: 44, avg: 177.99, max: 500)
#
# Run: 187, exploration: 0.01, score: 118
# Scores: (min: 44, avg: 177.58, max: 500)
#
# Run: 188, exploration: 0.01, score: 138
# Scores: (min: 44, avg: 177.77, max: 500)
#
# Run: 189, exploration: 0.01, score: 199
# Scores: (min: 44, avg: 178.09, max: 500)
#
# Run: 190, exploration: 0.01, score: 328
# Scores: (min: 44, avg: 180, max: 500)
#
# Run: 191, exploration: 0.01, score: 132
# Scores: (min: 44, avg: 179.57, max: 500)
#
# Run: 192, exploration: 0.01, score: 160
# Scores: (min: 44, avg: 180.19, max: 500)
#
# Run: 193, exploration: 0.01, score: 98
# Scores: (min: 44, avg: 178.99, max: 500)
# Run: 194, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 177.66, max: 500)
#
# Run: 195, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 176.55, max: 500)
#
# Run: 196, exploration: 0.01, score: 210
# Scores: (min: 11, avg: 175.79, max: 500)
#
# Run: 197, exploration: 0.01, score: 122
# Scores: (min: 11, avg: 176.01, max: 500)
#
# Run: 198, exploration: 0.01, score: 184
# Scores: (min: 11, avg: 176.86, max: 500)
#
# Run: 199, exploration: 0.01, score: 116
# Scores: (min: 11, avg: 175.8, max: 500)
#
# Run: 200, exploration: 0.01, score: 294
# Scores: (min: 11, avg: 176.86, max: 500)
#
# Run: 201, exploration: 0.01, score: 163
# Scores: (min: 11, avg: 176.28, max: 500)
#
# Run: 202, exploration: 0.01, score: 450
# Scores: (min: 11, avg: 179.23, max: 500)
#
# Run: 203, exploration: 0.01, score: 195
# Scores: (min: 11, avg: 178.95, max: 500)
#
# Run: 204, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 178.15, max: 500)
#
# Run: 205, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 178.68, max: 500)
#
# Run: 206, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 179.01, max: 500)
#
# Run: 207, exploration: 0.01, score: 194
# Scores: (min: 11, avg: 179.15, max: 500)
#
# Run: 208, exploration: 0.01, score: 185
# Scores: (min: 11, avg: 179.86, max: 500)
#
# Run: 209, exploration: 0.01, score: 236
# Scores: (min: 11, avg: 180.54, max: 500)
#
# Run: 210, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 179.72, max: 500)
#
# Run: 211, exploration: 0.01, score: 175
# Scores: (min: 11, avg: 179.85, max: 500)
#
# Run: 212, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 178.75, max: 500)
#
# Run: 213, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 177.2, max: 500)
#
# Run: 214, exploration: 0.01, score: 13
# Scores: (min: 11, avg: 175.66, max: 500)
#
# Run: 215, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 174.14, max: 500)
#
# Run: 216, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 173.57, max: 500)
#
# Run: 217, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 171.82, max: 500)
#
# Run: 218, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 169.55, max: 500)
#
# Run: 219, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 166.67, max: 500)
#
# Run: 220, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 165.56, max: 500)
#
# Run: 221, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 164.7, max: 500)
#
# Run: 222, exploration: 0.01, score: 212
# Scores: (min: 10, avg: 165.79, max: 500)
#
# Run: 223, exploration: 0.01, score: 102
# Scores: (min: 10, avg: 165.36, max: 500)
#
# Run: 224, exploration: 0.01, score: 371
# Scores: (min: 10, avg: 168.63, max: 500)
#
# Run: 225, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 168.24, max: 500)
#
# Run: 226, exploration: 0.01, score: 123
# Scores: (min: 10, avg: 167.76, max: 500)
#
# Run: 227, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 168.03, max: 500)
#
# Run: 228, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 169, max: 500)
#
# Run: 229, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 167.53, max: 500)
#
# Run: 230, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 168.02, max: 500)
#
# Run: 231, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 168.52, max: 500)
#
# Run: 232, exploration: 0.01, score: 130
# Scores: (min: 10, avg: 167.87, max: 500)
#
# Run: 233, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 167.51, max: 500)
#
# Run: 234, exploration: 0.01, score: 458
# Scores: (min: 10, avg: 170.22, max: 500)
#
# Run: 235, exploration: 0.01, score: 165
# Scores: (min: 10, avg: 171.07, max: 500)
#
# Run: 236, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 172.2, max: 500)
#
# Run: 237, exploration: 0.01, score: 57
# Scores: (min: 10, avg: 170.41, max: 500)
#
# Run: 238, exploration: 0.01, score: 327
# Scores: (min: 10, avg: 171.29, max: 500)
#
# Run: 239, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 170.95, max: 500)
#
# Run: 240, exploration: 0.01, score: 317
# Scores: (min: 10, avg: 172.69, max: 500)
#
# Run: 241, exploration: 0.01, score: 302
# Scores: (min: 10, avg: 174.12, max: 500)
#
# Run: 242, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 174.23, max: 500)
#
# Run: 243, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 172.46, max: 500)
#
# Run: 244, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 172.53, max: 500)
#
# Run: 245, exploration: 0.01, score: 68
# Scores: (min: 10, avg: 170.53, max: 500)
#
# Run: 246, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 168.94, max: 500)
#
# Run: 247, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 166.22, max: 500)
#
# Run: 248, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 164.11, max: 500)
#
# Run: 249, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 162.57, max: 500)
#
# Run: 250, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 157.69, max: 458)
#
# Run: 251, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 159.14, max: 458)
#
# Run: 252, exploration: 0.01, score: 133
# Scores: (min: 9, avg: 159.1, max: 458)
#
# Run: 253, exploration: 0.01, score: 249
# Scores: (min: 9, avg: 160.23, max: 458)
#
# Run: 254, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 159.62, max: 458)
#
# Run: 255, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 157.59, max: 458)
#
# Run: 256, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 157.88, max: 458)
#
# Run: 257, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 158.87, max: 458)
#
# Run: 258, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 158.56, max: 458)
#
# Run: 259, exploration: 0.01, score: 347
# Scores: (min: 9, avg: 160.08, max: 458)
#
# Run: 260, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 162.93, max: 500)
#
# Run: 261, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 164.28, max: 500)
#
# Run: 262, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 164.25, max: 500)
#
# Run: 263, exploration: 0.01, score: 213
# Scores: (min: 9, avg: 165.54, max: 500)
#
# Run: 264, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 165.16, max: 500)
#
# Run: 265, exploration: 0.01, score: 305
# Scores: (min: 9, avg: 167.07, max: 500)
#
# Run: 266, exploration: 0.01, score: 341
# Scores: (min: 9, avg: 168.78, max: 500)
#
# Run: 267, exploration: 0.01, score: 372
# Scores: (min: 9, avg: 170.74, max: 500)
#
# Run: 268, exploration: 0.01, score: 310
# Scores: (min: 9, avg: 171.14, max: 500)
#
# Run: 269, exploration: 0.01, score: 498
# Scores: (min: 9, avg: 174.45, max: 500)
#
# Run: 270, exploration: 0.01, score: 308
# Scores: (min: 9, avg: 176.01, max: 500)
#
# Run: 271, exploration: 0.01, score: 401
# Scores: (min: 9, avg: 177.54, max: 500)
#
# Run: 272, exploration: 0.01, score: 285
# Scores: (min: 9, avg: 179.04, max: 500)
#
# Run: 273, exploration: 0.01, score: 138
# Scores: (min: 9, avg: 177.37, max: 500)
#
# Run: 274, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 176.79, max: 500)
#
# Run: 275, exploration: 0.01, score: 80
# Scores: (min: 9, avg: 176.35, max: 500)
#
# Run: 276, exploration: 0.01, score: 170
# Scores: (min: 9, avg: 174.02, max: 500)
#
# Run: 277, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 173.09, max: 500)
#
# Run: 278, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 173.76, max: 500)
#
# Run: 279, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 174.68, max: 500)
#
# Run: 280, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 174.48, max: 500)
#
# Run: 281, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 174.34, max: 500)
#
# Run: 282, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 174.47, max: 500)
#
# Run: 283, exploration: 0.01, score: 492
# Scores: (min: 9, avg: 178.23, max: 500)
#
# Run: 284, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 178.87, max: 500)
#
# Run: 285, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 178.75, max: 500)
#
# Run: 286, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 178.76, max: 500)
#
# Run: 287, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 179.54, max: 500)
#
# Run: 288, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 179.69, max: 500)
#
# Run: 289, exploration: 0.01, score: 100
# Scores: (min: 9, avg: 178.7, max: 500)
#
# Run: 290, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 177.15, max: 500)
#
# Run: 291, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 177.23, max: 500)
#
# Run: 292, exploration: 0.01, score: 263
# Scores: (min: 9, avg: 178.26, max: 500)
#
# Run: 293, exploration: 0.01, score: 199
# Scores: (min: 9, avg: 179.27, max: 500)
#
# Run: 294, exploration: 0.01, score: 282
# Scores: (min: 9, avg: 181.98, max: 500)
# Run: 295, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 183.39, max: 500)
#
# Run: 296, exploration: 0.01, score: 248
# Scores: (min: 9, avg: 183.77, max: 500)
#
# Run: 297, exploration: 0.01, score: 466
# Scores: (min: 9, avg: 187.21, max: 500)
#
# Run: 298, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 187.08, max: 500)
#
# Run: 299, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 186.99, max: 500)
#
# Run: 300, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 184.3, max: 500)
#
# Run: 301, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 182.86, max: 500)
#
# Run: 302, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 178.54, max: 500)
#
# Run: 303, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 177.95, max: 500)
#
# Run: 304, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 178.39, max: 500)
#
# Run: 305, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 182.06, max: 500)
#
# Run: 306, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 180.76, max: 500)
#
# Run: 307, exploration: 0.01, score: 145
# Scores: (min: 9, avg: 180.27, max: 500)
#
# Run: 308, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 180.85, max: 500)
#
# Run: 309, exploration: 0.01, score: 115
# Scores: (min: 9, avg: 179.64, max: 500)
#
# Run: 310, exploration: 0.01, score: 243
# Scores: (min: 9, avg: 180.93, max: 500)
#
# Run: 311, exploration: 0.01, score: 261
# Scores: (min: 9, avg: 181.79, max: 500)
#
# Run: 312, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 182.49, max: 500)
#
# Run: 313, exploration: 0.01, score: 445
# Scores: (min: 9, avg: 186.8, max: 500)
#
# Run: 314, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 188.34, max: 500)
#
# Run: 315, exploration: 0.01, score: 106
# Scores: (min: 9, avg: 189.29, max: 500)
#
# Run: 316, exploration: 0.01, score: 183
# Scores: (min: 9, avg: 191.01, max: 500)
#
# Run: 317, exploration: 0.01, score: 135
# Scores: (min: 9, avg: 192.26, max: 500)
#
# Run: 318, exploration: 0.01, score: 96
# Scores: (min: 9, avg: 193.08, max: 500)
#
# Run: 319, exploration: 0.01, score: 58
# Scores: (min: 9, avg: 193.52, max: 500)
#
# Run: 320, exploration: 0.01, score: 67
# Scores: (min: 9, avg: 194.07, max: 500)
#
# Run: 321, exploration: 0.01, score: 25
# Scores: (min: 9, avg: 192.7, max: 500)
#
# Run: 322, exploration: 0.01, score: 59
# Scores: (min: 9, avg: 191.17, max: 500)
#
# Run: 323, exploration: 0.01, score: 35
# Scores: (min: 9, avg: 190.5, max: 500)
#
# Run: 324, exploration: 0.01, score: 23
# Scores: (min: 9, avg: 187.02, max: 500)
#
# Run: 325, exploration: 0.01, score: 49
# Scores: (min: 9, avg: 186.02, max: 500)
#
# Run: 326, exploration: 0.01, score: 469
# Scores: (min: 9, avg: 189.48, max: 500)
#
# Run: 327, exploration: 0.01, score: 163
# Scores: (min: 9, avg: 189.31, max: 500)
#
# Run: 328, exploration: 0.01, score: 168
# Scores: (min: 9, avg: 188.98, max: 500)
#
# Run: 329, exploration: 0.01, score: 95
# Scores: (min: 9, avg: 188.49, max: 500)
#
# Run: 330, exploration: 0.01, score: 443
# Scores: (min: 9, avg: 190.65, max: 500)
#
# Run: 331, exploration: 0.01, score: 119
# Scores: (min: 9, avg: 189.58, max: 500)
#
# Run: 332, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 190.32, max: 500)
#
# Run: 333, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 193.61, max: 500)
#
# Run: 334, exploration: 0.01, score: 97
# Scores: (min: 9, avg: 190, max: 500)
#
# Run: 335, exploration: 0.01, score: 203
# Scores: (min: 9, avg: 190.38, max: 500)
#
# Run: 336, exploration: 0.01, score: 124
# Scores: (min: 9, avg: 189.16, max: 500)
#
# Run: 337, exploration: 0.01, score: 425
# Scores: (min: 9, avg: 192.84, max: 500)
#
# Run: 338, exploration: 0.01, score: 365
# Scores: (min: 9, avg: 193.22, max: 500)
#
# Run: 339, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 193.16, max: 500)
#
# Run: 340, exploration: 0.01, score: 374
# Scores: (min: 9, avg: 193.73, max: 500)
#
# Run: 341, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 192.5, max: 500)
#
# Run: 342, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 192.75, max: 500)
#
# Run: 343, exploration: 0.01, score: 454
# Scores: (min: 9, avg: 196.26, max: 500)
#
# Solved in 243 runs, 343 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b2d6a8748ba2> in <module>
# ----> 1 cartpole() # Changed exploration max to 0.905
#
# <ipython-input-11-5179a7b95b70> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
cartpole() # Changed exploration min to 0.013
           # Solved in 23 runs, 123 total runs
# Out:
# Run: 1, exploration: 0.851801859600347, score: 52
# Scores: (min: 52, avg: 52, max: 52)
#
# Run: 2, exploration: 0.7292124703704616, score: 32
# Scores: (min: 32, avg: 42, max: 52)
#
# Run: 3, exploration: 0.6900935609921609, score: 12
# Scores: (min: 12, avg: 32, max: 52)
#
# Run: 4, exploration: 0.6274028820538087, score: 20
# Scores: (min: 12, avg: 29, max: 52)
#
# Run: 5, exploration: 0.5967292370047992, score: 11
# Scores: (min: 11, avg: 25.4, max: 52)
#
# Run: 6, exploration: 0.567555222460375, score: 11
# Scores: (min: 11, avg: 23, max: 52)
#
# Run: 7, exploration: 0.5032248303978422, score: 25
# Scores: (min: 11, avg: 23.285714285714285, max: 52)
#
# Run: 8, exploration: 0.4738479773082268, score: 13
# Scores: (min: 11, avg: 22, max: 52)
#
# Run: 9, exploration: 0.43296668905325736, score: 19
# Scores: (min: 11, avg: 21.666666666666668, max: 52)
#
# Run: 10, exploration: 0.40974000909221303, score: 12
# Scores: (min: 11, avg: 20.7, max: 52)
#
# Run: 11, exploration: 0.39166620452737816, score: 10
# Scores: (min: 10, avg: 19.727272727272727, max: 52)
#
# Run: 12, exploration: 0.3632974174544486, score: 16
# Scores: (min: 10, avg: 19.416666666666668, max: 52)
#
# Run: 13, exploration: 0.3352984938281715, score: 17
# Scores: (min: 10, avg: 19.23076923076923, max: 52)
#
# Run: 14, exploration: 0.3173112652388396, score: 12
# Scores: (min: 10, avg: 18.714285714285715, max: 52)
#
# Run: 15, exploration: 0.3033145315372582, score: 10
# Scores: (min: 10, avg: 18.133333333333333, max: 52)
#
# Run: 16, exploration: 0.28993519966087045, score: 10
# Scores: (min: 10, avg: 17.625, max: 52)
#
# Run: 17, exploration: 0.2799384215094006, score: 8
# Scores: (min: 8, avg: 17.058823529411764, max: 52)
#
# Run: 18, exploration: 0.26759021970270175, score: 10
# Scores: (min: 8, avg: 16.666666666666668, max: 52)
#
# Run: 19, exploration: 0.2519690537792925, score: 13
# Scores: (min: 8, avg: 16.473684210526315, max: 52)
#
# Run: 20, exploration: 0.23965031961336, score: 11
# Scores: (min: 8, avg: 16.2, max: 52)
#
# Run: 21, exploration: 0.22793384675362674, score: 11
# Scores: (min: 8, avg: 15.952380952380953, max: 52)
#
# Run: 22, exploration: 0.2167901907234072, score: 11
# Scores: (min: 8, avg: 15.727272727272727, max: 52)
#
# Run: 23, exploration: 0.2031139149609751, score: 14
# Scores: (min: 8, avg: 15.652173913043478, max: 52)
#
# Run: 24, exploration: 0.19318370215794672, score: 11
# Scores: (min: 8, avg: 15.458333333333334, max: 52)
#
# Run: 25, exploration: 0.1526354036900377, score: 48
# Scores: (min: 8, avg: 16.76, max: 52)
#
# Run: 26, exploration: 0.138769433003975, score: 20
# Scores: (min: 8, avg: 16.884615384615383, max: 52)
#
# Run: 27, exploration: 0.12490462201997637, score: 22
# Scores: (min: 8, avg: 17.074074074074073, max: 52)
#
# Run: 28, exploration: 0.10272559337455119, score: 40
# Scores: (min: 8, avg: 17.892857142857142, max: 52)
#
# Run: 29, exploration: 0.07955285615946175, score: 52
# Scores: (min: 8, avg: 19.06896551724138, max: 52)
#
# Run: 30, exploration: 0.0609928681304848, score: 54
# Scores: (min: 8, avg: 20.233333333333334, max: 54)
#
# Run: 31, exploration: 0.048190768399801194, score: 48
# Scores: (min: 8, avg: 21.129032258064516, max: 54)
#
# Run: 32, exploration: 0.03983280768576652, score: 39
# Scores: (min: 8, avg: 21.6875, max: 54)
#
# Run: 33, exploration: 0.02832764101944931, score: 69
# Scores: (min: 8, avg: 23.12121212121212, max: 69)
#
# Run: 34, exploration: 0.022158551474944856, score: 50
# Scores: (min: 8, avg: 23.91176470588235, max: 69)
#
# Run: 35, exploration: 0.018969543067746772, score: 32
# Scores: (min: 8, avg: 24.142857142857142, max: 69)
#
# Run: 36, exploration: 0.013, score: 81
# Scores: (min: 8, avg: 25.72222222222222, max: 81)
#
# Run: 37, exploration: 0.013, score: 94
# Scores: (min: 8, avg: 27.56756756756757, max: 94)
#
# Run: 38, exploration: 0.013, score: 63
# Scores: (min: 8, avg: 28.5, max: 94)
#
# Run: 39, exploration: 0.013, score: 66
# Scores: (min: 8, avg: 29.46153846153846, max: 94)
#
# Run: 40, exploration: 0.013, score: 86
# Scores: (min: 8, avg: 30.875, max: 94)
#
# Run: 41, exploration: 0.013, score: 10
# Scores: (min: 8, avg: 30.365853658536587, max: 94)
#
# Run: 42, exploration: 0.013, score: 10
# Scores: (min: 8, avg: 29.88095238095238, max: 94)
#
# Run: 43, exploration: 0.013, score: 86
# Scores: (min: 8, avg: 31.186046511627907, max: 94)
#
# Run: 44, exploration: 0.013, score: 82
# Scores: (min: 8, avg: 32.34090909090909, max: 94)
#
# Run: 45, exploration: 0.013, score: 119
# Scores: (min: 8, avg: 34.266666666666666, max: 119)
#
# Run: 46, exploration: 0.013, score: 154
# Scores: (min: 8, avg: 36.869565217391305, max: 154)
#
# Run: 47, exploration: 0.013, score: 175
# Scores: (min: 8, avg: 39.808510638297875, max: 175)
#
# Run: 48, exploration: 0.013, score: 285
# Scores: (min: 8, avg: 44.916666666666664, max: 285)
#
# Run: 49, exploration: 0.013, score: 157
# Scores: (min: 8, avg: 47.204081632653065, max: 285)
#
# Run: 50, exploration: 0.013, score: 206
# Scores: (min: 8, avg: 50.38, max: 285)
#
# Run: 51, exploration: 0.013, score: 211
# Scores: (min: 8, avg: 53.529411764705884, max: 285)
#
# Run: 52, exploration: 0.013, score: 500
# Scores: (min: 8, avg: 62.11538461538461, max: 500)
#
# Run: 53, exploration: 0.013, score: 279
# Scores: (min: 8, avg: 66.20754716981132, max: 500)
#
# Run: 54, exploration: 0.013, score: 288
# Scores: (min: 8, avg: 70.31481481481481, max: 500)
#
# Run: 55, exploration: 0.013, score: 337
# Scores: (min: 8, avg: 75.16363636363636, max: 500)
#
# Run: 56, exploration: 0.013, score: 487
# Scores: (min: 8, avg: 82.51785714285714, max: 500)
#
# Run: 57, exploration: 0.013, score: 272
# Scores: (min: 8, avg: 85.84210526315789, max: 500)
#
# Run: 58, exploration: 0.013, score: 500
# Scores: (min: 8, avg: 92.98275862068965, max: 500)
#
# Run: 59, exploration: 0.013, score: 271
# Scores: (min: 8, avg: 96, max: 500)
#
# Run: 60, exploration: 0.013, score: 218
# Scores: (min: 8, avg: 98.03333333333333, max: 500)
#
# Run: 61, exploration: 0.013, score: 226
# Scores: (min: 8, avg: 100.1311475409836, max: 500)
#
# Run: 62, exploration: 0.013, score: 499
# Scores: (min: 8, avg: 106.56451612903226, max: 500)
#
# Run: 63, exploration: 0.013, score: 466
# Scores: (min: 8, avg: 112.26984126984127, max: 500)
#
# Run: 64, exploration: 0.013, score: 334
# Scores: (min: 8, avg: 115.734375, max: 500)
#
# Run: 65, exploration: 0.013, score: 219
# Scores: (min: 8, avg: 117.32307692307693, max: 500)
#
# Run: 66, exploration: 0.013, score: 324
# Scores: (min: 8, avg: 120.45454545454545, max: 500)
#
# Run: 67, exploration: 0.013, score: 296
# Scores: (min: 8, avg: 123.07462686567165, max: 500)
#
# Run: 68, exploration: 0.013, score: 313
# Scores: (min: 8, avg: 125.86764705882354, max: 500)
#
# Run: 69, exploration: 0.013, score: 309
# Scores: (min: 8, avg: 128.52173913043478, max: 500)
#
# Run: 70, exploration: 0.013, score: 12
# Scores: (min: 8, avg: 126.85714285714286, max: 500)
#
# Run: 71, exploration: 0.013, score: 12
# Scores: (min: 8, avg: 125.2394366197183, max: 500)
#
# Run: 72, exploration: 0.013, score: 12
# Scores: (min: 8, avg: 123.66666666666667, max: 500)
#
# Run: 73, exploration: 0.013, score: 207
# Scores: (min: 8, avg: 124.8082191780822, max: 500)
#
# Run: 74, exploration: 0.013, score: 206
# Scores: (min: 8, avg: 125.9054054054054, max: 500)
#
# Run: 75, exploration: 0.013, score: 201
# Scores: (min: 8, avg: 126.90666666666667, max: 500)
#
# Run: 76, exploration: 0.013, score: 222
# Scores: (min: 8, avg: 128.1578947368421, max: 500)
#
# Run: 77, exploration: 0.013, score: 241
# Scores: (min: 8, avg: 129.62337662337663, max: 500)
#
# Run: 78, exploration: 0.013, score: 353
# Scores: (min: 8, avg: 132.48717948717947, max: 500)
#
# Run: 79, exploration: 0.013, score: 213
# Scores: (min: 8, avg: 133.50632911392404, max: 500)
#
# Run: 80, exploration: 0.013, score: 338
# Scores: (min: 8, avg: 136.0625, max: 500)
#
# Run: 81, exploration: 0.013, score: 205
# Scores: (min: 8, avg: 136.91358024691357, max: 500)
#
# Run: 82, exploration: 0.013, score: 166
# Scores: (min: 8, avg: 137.26829268292684, max: 500)
#
# Run: 83, exploration: 0.013, score: 211
# Scores: (min: 8, avg: 138.15662650602408, max: 500)
#
# Run: 84, exploration: 0.013, score: 283
# Scores: (min: 8, avg: 139.88095238095238, max: 500)
#
# Run: 85, exploration: 0.013, score: 294
# Scores: (min: 8, avg: 141.69411764705882, max: 500)
#
# Run: 86, exploration: 0.013, score: 225
# Scores: (min: 8, avg: 142.6627906976744, max: 500)
#
# Run: 87, exploration: 0.013, score: 267
# Scores: (min: 8, avg: 144.09195402298852, max: 500)
# Run: 88, exploration: 0.013, score: 307
# Scores: (min: 8, avg: 145.9431818181818, max: 500)
#
# Run: 89, exploration: 0.013, score: 351
# Scores: (min: 8, avg: 148.24719101123594, max: 500)
#
# Run: 90, exploration: 0.013, score: 230
# Scores: (min: 8, avg: 149.15555555555557, max: 500)
#
# Run: 91, exploration: 0.013, score: 168
# Scores: (min: 8, avg: 149.36263736263737, max: 500)
#
# Run: 92, exploration: 0.013, score: 203
# Scores: (min: 8, avg: 149.94565217391303, max: 500)
#
# Run: 93, exploration: 0.013, score: 227
# Scores: (min: 8, avg: 150.7741935483871, max: 500)
#
# Run: 94, exploration: 0.013, score: 193
# Scores: (min: 8, avg: 151.22340425531914, max: 500)
#
# Run: 95, exploration: 0.013, score: 280
# Scores: (min: 8, avg: 152.57894736842104, max: 500)
#
# Run: 96, exploration: 0.013, score: 219
# Scores: (min: 8, avg: 153.27083333333334, max: 500)
#
# Run: 97, exploration: 0.013, score: 279
# Scores: (min: 8, avg: 154.56701030927834, max: 500)
#
# Run: 98, exploration: 0.013, score: 206
# Scores: (min: 8, avg: 155.09183673469389, max: 500)
#
# Run: 99, exploration: 0.013, score: 219
# Scores: (min: 8, avg: 155.73737373737373, max: 500)
#
# Run: 100, exploration: 0.013, score: 186
# Scores: (min: 8, avg: 156.04, max: 500)
#
# Run: 101, exploration: 0.013, score: 157
# Scores: (min: 8, avg: 157.09, max: 500)
#
# Run: 102, exploration: 0.013, score: 100
# Scores: (min: 8, avg: 157.77, max: 500)
#
# Run: 103, exploration: 0.013, score: 197
# Scores: (min: 8, avg: 159.62, max: 500)
#
# Run: 104, exploration: 0.013, score: 47
# Scores: (min: 8, avg: 159.89, max: 500)
#
# Run: 105, exploration: 0.013, score: 176
# Scores: (min: 8, avg: 161.54, max: 500)
#
# Run: 106, exploration: 0.013, score: 143
# Scores: (min: 8, avg: 162.86, max: 500)
#
# Run: 107, exploration: 0.013, score: 172
# Scores: (min: 8, avg: 164.33, max: 500)
#
# Run: 108, exploration: 0.013, score: 237
# Scores: (min: 8, avg: 166.57, max: 500)
#
# Run: 109, exploration: 0.013, score: 229
# Scores: (min: 8, avg: 168.67, max: 500)
#
# Run: 110, exploration: 0.013, score: 217
# Scores: (min: 8, avg: 170.72, max: 500)
#
# Run: 111, exploration: 0.013, score: 217
# Scores: (min: 8, avg: 172.79, max: 500)
#
# Run: 112, exploration: 0.013, score: 39
# Scores: (min: 8, avg: 173.02, max: 500)
#
# Run: 113, exploration: 0.013, score: 124
# Scores: (min: 8, avg: 174.09, max: 500)
#
# Run: 114, exploration: 0.013, score: 231
# Scores: (min: 8, avg: 176.28, max: 500)
#
# Run: 115, exploration: 0.013, score: 198
# Scores: (min: 8, avg: 178.16, max: 500)
#
# Run: 116, exploration: 0.013, score: 104
# Scores: (min: 8, avg: 179.1, max: 500)
#
# Run: 117, exploration: 0.013, score: 267
# Scores: (min: 10, avg: 181.69, max: 500)
#
# Run: 118, exploration: 0.013, score: 268
# Scores: (min: 10, avg: 184.27, max: 500)
#
# Run: 119, exploration: 0.013, score: 212
# Scores: (min: 10, avg: 186.26, max: 500)
#
# Run: 120, exploration: 0.013, score: 312
# Scores: (min: 10, avg: 189.27, max: 500)
#
# Run: 121, exploration: 0.013, score: 143
# Scores: (min: 10, avg: 190.59, max: 500)
#
# Run: 122, exploration: 0.013, score: 213
# Scores: (min: 10, avg: 192.61, max: 500)
#
# Run: 123, exploration: 0.013, score: 393
# Scores: (min: 10, avg: 196.4, max: 500)
#
# Solved in 23 runs, 123 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b4ab9b022371> in <module>
# ----> 1 cartpole() # Changed exploration min to 0.013
#
# <ipython-input-9-1a5ed7441a58> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
cartpole() # Changed exploration max to 0.8 results below
           # Solved in 14 runs, 114 total runs
# Out:
# Run: 1, exploration: 0.7685544348603495, score: 28
# Scores: (min: 28, avg: 28, max: 28)
#
# Run: 2, exploration: 0.6712708882964634, score: 28
# Scores: (min: 28, avg: 28, max: 28)
#
# Run: 3, exploration: 0.6102901313127972, score: 20
# Scores: (min: 20, avg: 25.333333333333332, max: 28)
#
# Run: 4, exploration: 0.5717897909465046, score: 14
# Scores: (min: 14, avg: 22.5, max: 28)
#
# Run: 5, exploration: 0.5224585615557593, score: 19
# Scores: (min: 14, avg: 21.8, max: 28)
#
# Run: 6, exploration: 0.4894991027424384, score: 14
# Scores: (min: 14, avg: 20.5, max: 28)
#
# Run: 7, exploration: 0.38098329833827305, score: 51
# Scores: (min: 14, avg: 24.857142857142858, max: 51)
#
# Run: 8, exploration: 0.3412036856786414, score: 23
# Scores: (min: 14, avg: 24.625, max: 51)
#
# Run: 9, exploration: 0.3055775820842425, score: 23
# Scores: (min: 14, avg: 24.444444444444443, max: 51)
#
# Run: 10, exploration: 0.26159955042365357, score: 32
# Scores: (min: 14, avg: 25.2, max: 51)
#
# Run: 11, exploration: 0.16330767032038201, score: 95
# Scores: (min: 14, avg: 31.545454545454547, max: 95)
#
# Run: 12, exploration: 0.13098517244712451, score: 45
# Scores: (min: 14, avg: 32.666666666666664, max: 95)
#
# Run: 13, exploration: 0.07000148117199358, score: 126
# Scores: (min: 14, avg: 39.84615384615385, max: 126)
#
# Run: 14, exploration: 0.03933340239959077, score: 116
# Scores: (min: 14, avg: 45.285714285714285, max: 126)
#
# Run: 15, exploration: 0.017201639358753833, score: 166
# Scores: (min: 14, avg: 53.333333333333336, max: 166)
#
# Run: 16, exploration: 0.01, score: 122
# Scores: (min: 14, avg: 57.625, max: 166)
#
# Run: 17, exploration: 0.01, score: 163
# Scores: (min: 14, avg: 63.8235294117647, max: 166)
#
# Run: 18, exploration: 0.01, score: 192
# Scores: (min: 14, avg: 70.94444444444444, max: 192)
#
# Run: 19, exploration: 0.01, score: 150
# Scores: (min: 14, avg: 75.10526315789474, max: 192)
#
# Run: 20, exploration: 0.01, score: 80
# Scores: (min: 14, avg: 75.35, max: 192)
#
# Run: 21, exploration: 0.01, score: 19
# Scores: (min: 14, avg: 72.66666666666667, max: 192)
#
# Run: 22, exploration: 0.01, score: 192
# Scores: (min: 14, avg: 78.0909090909091, max: 192)
#
# Run: 23, exploration: 0.01, score: 135
# Scores: (min: 14, avg: 80.56521739130434, max: 192)
#
# Run: 24, exploration: 0.01, score: 157
# Scores: (min: 14, avg: 83.75, max: 192)
#
# Run: 25, exploration: 0.01, score: 194
# Scores: (min: 14, avg: 88.16, max: 194)
#
# Run: 26, exploration: 0.01, score: 158
# Scores: (min: 14, avg: 90.84615384615384, max: 194)
#
# Run: 27, exploration: 0.01, score: 209
# Scores: (min: 14, avg: 95.22222222222223, max: 209)
#
# Run: 28, exploration: 0.01, score: 175
# Scores: (min: 14, avg: 98.07142857142857, max: 209)
#
# Run: 29, exploration: 0.01, score: 219
# Scores: (min: 14, avg: 102.24137931034483, max: 219)
#
# Run: 30, exploration: 0.01, score: 169
# Scores: (min: 14, avg: 104.46666666666667, max: 219)
#
# Run: 31, exploration: 0.01, score: 167
# Scores: (min: 14, avg: 106.48387096774194, max: 219)
#
# Run: 32, exploration: 0.01, score: 172
# Scores: (min: 14, avg: 108.53125, max: 219)
#
# Run: 33, exploration: 0.01, score: 156
# Scores: (min: 14, avg: 109.96969696969697, max: 219)
#
# Run: 34, exploration: 0.01, score: 139
# Scores: (min: 14, avg: 110.82352941176471, max: 219)
#
# Run: 35, exploration: 0.01, score: 178
# Scores: (min: 14, avg: 112.74285714285715, max: 219)
#
# Run: 36, exploration: 0.01, score: 173
# Scores: (min: 14, avg: 114.41666666666667, max: 219)
#
# Run: 37, exploration: 0.01, score: 197
# Scores: (min: 14, avg: 116.64864864864865, max: 219)
#
# Run: 38, exploration: 0.01, score: 191
# Scores: (min: 14, avg: 118.60526315789474, max: 219)
#
# Run: 39, exploration: 0.01, score: 143
# Scores: (min: 14, avg: 119.23076923076923, max: 219)
#
# Run: 40, exploration: 0.01, score: 193
# Scores: (min: 14, avg: 121.075, max: 219)
#
# Run: 41, exploration: 0.01, score: 177
# Scores: (min: 14, avg: 122.4390243902439, max: 219)
#
# Run: 42, exploration: 0.01, score: 158
# Scores: (min: 14, avg: 123.28571428571429, max: 219)
#
# Run: 43, exploration: 0.01, score: 173
# Scores: (min: 14, avg: 124.44186046511628, max: 219)
#
# Run: 44, exploration: 0.01, score: 112
# Scores: (min: 14, avg: 124.1590909090909, max: 219)
#
# Run: 45, exploration: 0.01, score: 217
# Scores: (min: 14, avg: 126.22222222222223, max: 219)
#
# Run: 46, exploration: 0.01, score: 161
# Scores: (min: 14, avg: 126.97826086956522, max: 219)
#
# Run: 47, exploration: 0.01, score: 144
# Scores: (min: 14, avg: 127.34042553191489, max: 219)
#
# Run: 48, exploration: 0.01, score: 175
# Scores: (min: 14, avg: 128.33333333333334, max: 219)
#
# Run: 49, exploration: 0.01, score: 181
# Scores: (min: 14, avg: 129.40816326530611, max: 219)
#
# Run: 50, exploration: 0.01, score: 246
# Scores: (min: 14, avg: 131.74, max: 246)
#
# Run: 51, exploration: 0.01, score: 249
# Scores: (min: 14, avg: 134.0392156862745, max: 249)
#
# Run: 52, exploration: 0.01, score: 187
# Scores: (min: 14, avg: 135.05769230769232, max: 249)
#
# Run: 53, exploration: 0.01, score: 193
# Scores: (min: 14, avg: 136.1509433962264, max: 249)
#
# Run: 54, exploration: 0.01, score: 206
# Scores: (min: 14, avg: 137.44444444444446, max: 249)
#
# Run: 55, exploration: 0.01, score: 192
# Scores: (min: 14, avg: 138.43636363636364, max: 249)
#
# Run: 56, exploration: 0.01, score: 186
# Scores: (min: 14, avg: 139.28571428571428, max: 249)
#
# Run: 57, exploration: 0.01, score: 167
# Scores: (min: 14, avg: 139.7719298245614, max: 249)
#
# Run: 58, exploration: 0.01, score: 175
# Scores: (min: 14, avg: 140.3793103448276, max: 249)
#
# Run: 59, exploration: 0.01, score: 189
# Scores: (min: 14, avg: 141.20338983050848, max: 249)
#
# Run: 60, exploration: 0.01, score: 187
# Scores: (min: 14, avg: 141.96666666666667, max: 249)
#
# Run: 61, exploration: 0.01, score: 167
# Scores: (min: 14, avg: 142.37704918032787, max: 249)
#
# Run: 62, exploration: 0.01, score: 184
# Scores: (min: 14, avg: 143.0483870967742, max: 249)
#
# Run: 63, exploration: 0.01, score: 175
# Scores: (min: 14, avg: 143.55555555555554, max: 249)
#
# Run: 64, exploration: 0.01, score: 164
# Scores: (min: 14, avg: 143.875, max: 249)
#
# Run: 65, exploration: 0.01, score: 183
# Scores: (min: 14, avg: 144.47692307692307, max: 249)
#
# Run: 66, exploration: 0.01, score: 243
# Scores: (min: 14, avg: 145.96969696969697, max: 249)
#
# Run: 67, exploration: 0.01, score: 195
# Scores: (min: 14, avg: 146.70149253731344, max: 249)
#
# Run: 68, exploration: 0.01, score: 207
# Scores: (min: 14, avg: 147.58823529411765, max: 249)
#
# Run: 69, exploration: 0.01, score: 13
# Scores: (min: 13, avg: 145.63768115942028, max: 249)
#
# Run: 70, exploration: 0.01, score: 199
# Scores: (min: 13, avg: 146.4, max: 249)
#
# Run: 71, exploration: 0.01, score: 92
# Scores: (min: 13, avg: 145.6338028169014, max: 249)
#
# Run: 72, exploration: 0.01, score: 195
# Scores: (min: 13, avg: 146.31944444444446, max: 249)
#
# Run: 73, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 151.16438356164383, max: 500)
#
# Run: 74, exploration: 0.01, score: 232
# Scores: (min: 13, avg: 152.25675675675674, max: 500)
#
# Run: 75, exploration: 0.01, score: 237
# Scores: (min: 13, avg: 153.38666666666666, max: 500)
#
# Run: 76, exploration: 0.01, score: 257
# Scores: (min: 13, avg: 154.75, max: 500)
#
# Run: 77, exploration: 0.01, score: 132
# Scores: (min: 13, avg: 154.45454545454547, max: 500)
#
# Run: 78, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 154.25641025641025, max: 500)
#
# Run: 79, exploration: 0.01, score: 227
# Scores: (min: 13, avg: 155.1772151898734, max: 500)
#
# Run: 80, exploration: 0.01, score: 198
# Scores: (min: 13, avg: 155.7125, max: 500)
#
# Run: 81, exploration: 0.01, score: 133
# Scores: (min: 13, avg: 155.4320987654321, max: 500)
#
# Run: 82, exploration: 0.01, score: 214
# Scores: (min: 13, avg: 156.14634146341464, max: 500)
#
# Run: 83, exploration: 0.01, score: 482
# Scores: (min: 13, avg: 160.0722891566265, max: 500)
#
# Run: 84, exploration: 0.01, score: 422
# Scores: (min: 13, avg: 163.1904761904762, max: 500)
#
# Run: 85, exploration: 0.01, score: 152
# Scores: (min: 13, avg: 163.05882352941177, max: 500)
#
# Run: 86, exploration: 0.01, score: 105
# Scores: (min: 13, avg: 162.38372093023256, max: 500)
#
# Run: 87, exploration: 0.01, score: 153
# Scores: (min: 13, avg: 162.27586206896552, max: 500)
#
# Run: 88, exploration: 0.01, score: 135
# Scores: (min: 13, avg: 161.9659090909091, max: 500)
#
# Run: 89, exploration: 0.01, score: 216
# Scores: (min: 13, avg: 162.57303370786516, max: 500)
# Run: 90, exploration: 0.01, score: 170
# Scores: (min: 13, avg: 162.65555555555557, max: 500)
#
# Run: 91, exploration: 0.01, score: 190
# Scores: (min: 13, avg: 162.95604395604394, max: 500)
#
# Run: 92, exploration: 0.01, score: 189
# Scores: (min: 13, avg: 163.2391304347826, max: 500)
#
# Run: 93, exploration: 0.01, score: 186
# Scores: (min: 13, avg: 163.48387096774192, max: 500)
#
# Run: 94, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 167.06382978723406, max: 500)
#
# Run: 95, exploration: 0.01, score: 165
# Scores: (min: 13, avg: 167.0421052631579, max: 500)
#
# Run: 96, exploration: 0.01, score: 280
# Scores: (min: 13, avg: 168.21875, max: 500)
#
# Run: 97, exploration: 0.01, score: 159
# Scores: (min: 13, avg: 168.1237113402062, max: 500)
#
# Run: 98, exploration: 0.01, score: 275
# Scores: (min: 13, avg: 169.21428571428572, max: 500)
#
# Run: 99, exploration: 0.01, score: 119
# Scores: (min: 13, avg: 168.7070707070707, max: 500)
#
# Run: 100, exploration: 0.01, score: 185
# Scores: (min: 13, avg: 168.87, max: 500)
#
# Run: 101, exploration: 0.01, score: 179
# Scores: (min: 13, avg: 170.38, max: 500)
#
# Run: 102, exploration: 0.01, score: 344
# Scores: (min: 13, avg: 173.54, max: 500)
#
# Run: 103, exploration: 0.01, score: 203
# Scores: (min: 13, avg: 175.37, max: 500)
#
# Run: 104, exploration: 0.01, score: 468
# Scores: (min: 13, avg: 179.91, max: 500)
#
# Run: 105, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 184.72, max: 500)
#
# Run: 106, exploration: 0.01, score: 142
# Scores: (min: 13, avg: 186, max: 500)
#
# Run: 107, exploration: 0.01, score: 205
# Scores: (min: 13, avg: 187.54, max: 500)
#
# Run: 108, exploration: 0.01, score: 280
# Scores: (min: 13, avg: 190.11, max: 500)
#
# Run: 109, exploration: 0.01, score: 150
# Scores: (min: 13, avg: 191.38, max: 500)
#
# Run: 110, exploration: 0.01, score: 142
# Scores: (min: 13, avg: 192.48, max: 500)
#
# Run: 111, exploration: 0.01, score: 151
# Scores: (min: 13, avg: 193.04, max: 500)
#
# Run: 112, exploration: 0.01, score: 133
# Scores: (min: 13, avg: 193.92, max: 500)
#
# Run: 113, exploration: 0.01, score: 223
# Scores: (min: 13, avg: 194.89, max: 500)
#
# Run: 114, exploration: 0.01, score: 152
# Scores: (min: 13, avg: 195.25, max: 500)
#
# Solved in 14 runs, 114 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f6fe72052135> in <module>
# ----> 1 cartpole() # Changed exploration max to 0.8
#
# <ipython-input-5-e38d4d1f8284> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
cartpole() # No changes made - Results below
           # Solved in 12 runs, 112 total runs
# Out:
# Run: 1, exploration: 1.0, score: 11
# Scores: (min: 11, avg: 11, max: 11)
#
# Run: 2, exploration: 0.8603841919146962, score: 39
# Scores: (min: 11, avg: 25, max: 39)
#
# Run: 3, exploration: 0.7901049725470279, score: 18
# Scores: (min: 11, avg: 22.666666666666668, max: 39)
#
# Run: 4, exploration: 0.736559652908221, score: 15
# Scores: (min: 11, avg: 20.75, max: 39)
#
# Run: 5, exploration: 0.7076077347272662, score: 9
# Scores: (min: 9, avg: 18.4, max: 39)
#
# Run: 6, exploration: 0.6763948591909945, score: 10
# Scores: (min: 9, avg: 17, max: 39)
#
# Run: 7, exploration: 0.6088145090359074, score: 22
# Scores: (min: 9, avg: 17.714285714285715, max: 39)
#
# Run: 8, exploration: 0.5790496471185967, score: 11
# Scores: (min: 9, avg: 16.875, max: 39)
#
# Run: 9, exploration: 0.5562889678716474, score: 9
# Scores: (min: 9, avg: 16, max: 39)
#
# Run: 10, exploration: 0.5344229416520513, score: 9
# Scores: (min: 9, avg: 15.3, max: 39)
#
# Run: 11, exploration: 0.4883155414435353, score: 19
# Scores: (min: 9, avg: 15.636363636363637, max: 39)
#
# Run: 12, exploration: 0.4598090507939749, score: 13
# Scores: (min: 9, avg: 15.416666666666666, max: 39)
#
# Run: 13, exploration: 0.43732904629000013, score: 11
# Scores: (min: 9, avg: 15.076923076923077, max: 39)
#
# Run: 14, exploration: 0.41386834584198684, score: 12
# Scores: (min: 9, avg: 14.857142857142858, max: 39)
#
# Run: 15, exploration: 0.3976004408064698, score: 9
# Scores: (min: 9, avg: 14.466666666666667, max: 39)
#
# Run: 16, exploration: 0.37251769488706843, score: 14
# Scores: (min: 9, avg: 14.4375, max: 39)
#
# Run: 17, exploration: 0.3543053533848483, score: 11
# Scores: (min: 9, avg: 14.235294117647058, max: 39)
#
# Run: 18, exploration: 0.3420891339682016, score: 8
# Scores: (min: 8, avg: 13.88888888888889, max: 39)
#
# Run: 19, exploration: 0.3253644408394192, score: 11
# Scores: (min: 8, avg: 13.736842105263158, max: 39)
#
# Run: 20, exploration: 0.30945741577570285, score: 11
# Scores: (min: 8, avg: 13.6, max: 39)
#
# Run: 21, exploration: 0.2913921604631864, score: 13
# Scores: (min: 8, avg: 13.571428571428571, max: 39)
#
# Run: 22, exploration: 0.27714603575484437, score: 11
# Scores: (min: 8, avg: 13.454545454545455, max: 39)
#
# Run: 23, exploration: 0.26227842021373715, score: 12
# Scores: (min: 8, avg: 13.391304347826088, max: 39)
#
# Run: 24, exploration: 0.2494556624678441, score: 11
# Scores: (min: 8, avg: 13.291666666666666, max: 39)
#
# Run: 25, exploration: 0.23725980767521673, score: 11
# Scores: (min: 8, avg: 13.2, max: 39)
#
# Run: 26, exploration: 0.22340924607110255, score: 13
# Scores: (min: 8, avg: 13.192307692307692, max: 39)
#
# Run: 27, exploration: 0.21248679717794605, score: 11
# Scores: (min: 8, avg: 13.11111111111111, max: 39)
#
# Run: 28, exploration: 0.2010878536592394, score: 12
# Scores: (min: 8, avg: 13.071428571428571, max: 39)
#
# Run: 29, exploration: 0.1912566947289212, score: 11
# Scores: (min: 8, avg: 13, max: 39)
#
# Run: 30, exploration: 0.182820281282489, score: 10
# Scores: (min: 8, avg: 12.9, max: 39)
#
# Run: 31, exploration: 0.17388222158237718, score: 11
# Scores: (min: 8, avg: 12.838709677419354, max: 39)
#
# Run: 32, exploration: 0.16538114245489302, score: 11
# Scores: (min: 8, avg: 12.78125, max: 39)
#
# Run: 33, exploration: 0.15035730121053842, score: 20
# Scores: (min: 8, avg: 13, max: 39)
#
# Run: 34, exploration: 0.10376060541355137, score: 75
# Scores: (min: 8, avg: 14.823529411764707, max: 75)
#
# Run: 35, exploration: 0.08448484422350626, score: 42
# Scores: (min: 8, avg: 15.6, max: 75)
#
# Run: 36, exploration: 0.06509970288011008, score: 53
# Scores: (min: 8, avg: 16.63888888888889, max: 75)
#
# Run: 37, exploration: 0.03845939824099909, score: 106
# Scores: (min: 8, avg: 19.054054054054053, max: 106)
#
# Run: 38, exploration: 0.027626496583102015, score: 67
# Scores: (min: 8, avg: 20.31578947368421, max: 106)
#
# Run: 39, exploration: 0.017332943577287888, score: 94
# Scores: (min: 8, avg: 22.205128205128204, max: 106)
#
# Run: 40, exploration: 0.011150733307840981, score: 89
# Scores: (min: 8, avg: 23.875, max: 106)
#
# Run: 41, exploration: 0.01, score: 182
# Scores: (min: 8, avg: 27.73170731707317, max: 182)
#
# Run: 42, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 32.642857142857146, max: 234)
#
# Run: 43, exploration: 0.01, score: 99
# Scores: (min: 8, avg: 34.18604651162791, max: 234)
#
# Run: 44, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 34.90909090909091, max: 234)
#
# Run: 45, exploration: 0.01, score: 134
# Scores: (min: 8, avg: 37.111111111111114, max: 234)
#
# Run: 46, exploration: 0.01, score: 234
# Scores: (min: 8, avg: 41.391304347826086, max: 234)
#
# Run: 47, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 46.765957446808514, max: 294)
#
# Run: 48, exploration: 0.01, score: 303
# Scores: (min: 8, avg: 52.104166666666664, max: 303)
#
# Run: 49, exploration: 0.01, score: 409
# Scores: (min: 8, avg: 59.38775510204081, max: 409)
#
# Run: 50, exploration: 0.01, score: 343
# Scores: (min: 8, avg: 65.06, max: 409)
#
# Run: 51, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 69.74509803921569, max: 409)
#
# Run: 52, exploration: 0.01, score: 461
# Scores: (min: 8, avg: 77.26923076923077, max: 461)
#
# Run: 53, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 79.88679245283019, max: 461)
#
# Run: 54, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 83.42592592592592, max: 461)
#
# Run: 55, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 86.36363636363636, max: 461)
#
# Run: 56, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 88.71428571428571, max: 461)
#
# Run: 57, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 91.33333333333333, max: 461)
#
# Run: 58, exploration: 0.01, score: 253
# Scores: (min: 8, avg: 94.12068965517241, max: 461)
#
# Run: 59, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 95.40677966101696, max: 461)
#
# Run: 60, exploration: 0.01, score: 277
# Scores: (min: 8, avg: 98.43333333333334, max: 461)
#
# Run: 61, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 101.0327868852459, max: 461)
#
# Run: 62, exploration: 0.01, score: 313
# Scores: (min: 8, avg: 104.45161290322581, max: 461)
#
# Run: 63, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 106.92063492063492, max: 461)
#
# Run: 64, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 108.890625, max: 461)
#
# Run: 65, exploration: 0.01, score: 448
# Scores: (min: 8, avg: 114.1076923076923, max: 461)
#
# Run: 66, exploration: 0.01, score: 279
# Scores: (min: 8, avg: 116.60606060606061, max: 461)
#
# Run: 67, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 118.44776119402985, max: 461)
#
# Run: 68, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 119.83823529411765, max: 461)
#
# Run: 69, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 121.23188405797102, max: 461)
#
# Run: 70, exploration: 0.01, score: 320
# Scores: (min: 8, avg: 124.07142857142857, max: 461)
#
# Run: 71, exploration: 0.01, score: 249
# Scores: (min: 8, avg: 125.83098591549296, max: 461)
#
# Run: 72, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 127.44444444444444, max: 461)
#
# Run: 73, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 128.02739726027397, max: 461)
#
# Run: 74, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 129.02702702702703, max: 461)
#
# Run: 75, exploration: 0.01, score: 313
# Scores: (min: 8, avg: 131.48, max: 461)
#
# Run: 76, exploration: 0.01, score: 342
# Scores: (min: 8, avg: 134.25, max: 461)
#
# Run: 77, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 135.3116883116883, max: 461)
#
# Run: 78, exploration: 0.01, score: 480
# Scores: (min: 8, avg: 139.73076923076923, max: 480)
#
# Run: 79, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 141.0126582278481, max: 480)
#
# Run: 80, exploration: 0.01, score: 345
# Scores: (min: 8, avg: 143.5625, max: 480)
#
# Run: 81, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 144.7037037037037, max: 480)
#
# Run: 82, exploration: 0.01, score: 366
# Scores: (min: 8, avg: 147.40243902439025, max: 480)
#
# Run: 83, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 148.66265060240963, max: 480)
#
# Run: 84, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 152.8452380952381, max: 500)
#
# Run: 85, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 153.6235294117647, max: 500)
#
# Run: 86, exploration: 0.01, score: 268
# Scores: (min: 8, avg: 154.95348837209303, max: 500)
#
# Run: 87, exploration: 0.01, score: 410
# Scores: (min: 8, avg: 157.88505747126436, max: 500)
#
# Run: 88, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 158.36363636363637, max: 500)
# Run: 89, exploration: 0.01, score: 328
# Scores: (min: 8, avg: 160.26966292134833, max: 500)
#
# Run: 90, exploration: 0.01, score: 232
# Scores: (min: 8, avg: 161.06666666666666, max: 500)
#
# Run: 91, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 161.26373626373626, max: 500)
#
# Run: 92, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 161.66304347826087, max: 500)
#
# Run: 93, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 162.3763440860215, max: 500)
#
# Run: 94, exploration: 0.01, score: 247
# Scores: (min: 8, avg: 163.27659574468086, max: 500)
#
# Run: 95, exploration: 0.01, score: 415
# Scores: (min: 8, avg: 165.92631578947368, max: 500)
#
# Run: 96, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 166.70833333333334, max: 500)
#
# Run: 97, exploration: 0.01, score: 327
# Scores: (min: 8, avg: 168.36082474226805, max: 500)
#
# Run: 98, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 169.3265306122449, max: 500)
#
# Run: 99, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 169.7979797979798, max: 500)
#
# Run: 100, exploration: 0.01, score: 323
# Scores: (min: 8, avg: 171.33, max: 500)
#
# Run: 101, exploration: 0.01, score: 348
# Scores: (min: 8, avg: 174.7, max: 500)
#
# Run: 102, exploration: 0.01, score: 305
# Scores: (min: 8, avg: 177.36, max: 500)
#
# Run: 103, exploration: 0.01, score: 178
# Scores: (min: 8, avg: 178.96, max: 500)
#
# Run: 104, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 179.33, max: 500)
#
# Run: 105, exploration: 0.01, score: 255
# Scores: (min: 8, avg: 181.79, max: 500)
#
# Run: 106, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 181.89, max: 500)
#
# Run: 107, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 181.86, max: 500)
#
# Run: 108, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 184.1, max: 500)
#
# Run: 109, exploration: 0.01, score: 306
# Scores: (min: 8, avg: 187.07, max: 500)
#
# Run: 110, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 191.98, max: 500)
#
# Run: 111, exploration: 0.01, score: 284
# Scores: (min: 8, avg: 194.63, max: 500)
#
# Run: 112, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 197.14, max: 500)
#
# Solved in 12 runs, 112 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-27e785059a3b> in cartpole()
#      83             if terminal:
#      84                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 85                 score_logger.add_score(step, run)
#      86                 break
#      87             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %% [markdown]
# # Markdown - Assignment 5
#
# ## Analysis of CartPole Problem and Q-learning
#
# ### Reinforcement Learning Concepts for the Cartpole Problem
# Reinforcement learning is applied to the CartPole problem by training an agent to balance a pole on a moving cart. The agent's goal is to maximize its cumulative reward over time. The state values represent the current state of the environment, which includes the cart's position, velocity, pole angle, and pole angular velocity. Possible actions include moving the cart left or right. The reinforcement algorithm used is a form of Q-learning, where the agent learns a Q-value function to estimate the expected future rewards for each state-action pair.
#
# ### Experience Replay in the Cartpole Problem
# Experience replay is applied to the CartPole problem by storing past experiences (state, action, reward, next state) in a replay buffer. During training, random batches of experiences are sampled from the buffer, breaking the temporal correlation between consecutive samples, thus improving the stability of the learning process.
#
# ### Neural Networks in the Cartpole Problem
# Deep Q-learning employs a neural network to approximate the Q-value function. The architecture typically consists of input nodes representing the state space, hidden layers for complex feature representation, and output nodes for each possible action. This neural network makes the Q-learning algorithm more efficient by generalizing Q-values across similar states.
#
# ### Effect of Modifying Parameters
#
# #### Modifying Discount Factor (Gamma)
# *Changed gamma to 0.9.*
# **Result:** Solved in 76 runs out of 176 total runs.
# **Analysis:** A discount factor of 0.9 likely emphasizes short-term rewards slightly more than the default, influencing the agent to prioritize immediate gains.
#
# #### Modifying Learning Rate and Decay
# *Changed learning rate to 0.004 and decay to 0.905.*
# **Result:** Force stopped after 1195 runs over an hour.
# **Analysis:** A lower learning rate and higher decay might lead to slower convergence, and in this case, it resulted in a prolonged training time without finding a solution.
#
# #### Modifying Exploration Max
# *Changed exploration max to 0.8.*
# **Result:** Solved in 14 runs out of 114 total runs.
# **Analysis:** Decreasing exploration max seems to have allowed the agent to explore more states, leading to a successful solution but with a higher number of runs.
#
# #### Modifying Exploration Min
# *Changed exploration min to 0.013.*
# **Result:** Solved in 23 runs out of 123 total runs.
# **Analysis:** Decreasing exploration min likely encouraged more exploration, helping the agent find a solution faster.
#
# #### Modifying Exploration Decay
# *Changed exploration decay to 0.905.*
# **Result:** Solved in 243 runs out of 343 total runs.
# **Analysis:** Increasing exploration decay seems to have allowed the agent to explore more effectively and find a solution.
#
# #### No Changes Made
# **Result:** Solved in 12 runs out of 112 total runs.
# **Analysis:** The default parameters seem to perform reasonably well, solving the problem in a relatively low number of runs.
#
# ### Citations and Attributions
# [Surma, G. (2018). Cartpole. Github repository.](https://github.com/gsurma/cartpole)
